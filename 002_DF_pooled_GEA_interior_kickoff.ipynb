# %% [markdown]
# This notebook best viewed here: https://nbviewer.jupyter.org

# %% [markdown]
# This notebook is for the interior variety of Douglas fir GEA mapping pops
#
# - First I LD-prune SNPs to use for structure correction in baypass.
# - Then I use LD-pruned SNPs to estimate the covariance matrix across 5 independent runs of the core mode of baypass, and to ensure convergence I calculate the pairwise correlation of the matrices across runs (I found that these runs were highly correlated, r2 > 0.998).
# - Then I run baypass in STD mode (mcmc) for SNPs in our data.

# %%
from pythonimports import *

DIR = '/data/projects/pool_seq/DF_datasets'
snpdir = op.join(DIR, 'DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI')
assert op.exists(snpdir)
baydir = makedir(op.join(snpdir, 'baypass'))
op.exists(baydir)
# Out:
# True

# %% [markdown]
# # Choose SNPs for GEA structure correction in baypass
#
# First choose loci for each variety (coastal and interior) then choose loci across both.
#
# for SNPs with MAF > 0.05 and for all pops: 40 < DP < 1000, randomly choose one snp per contig (for contigs > 1Kbp), then LD prune so no pairwise r2 > 99.9th percentile of r2

# %% [markdown]
# #### get the snps

# %%
lview,dview = get_client()
# Out:
# 56 56

# %%
def get_mafdict(series, roundto, count=True):
    series = [round(x, roundto) for x in series]
    t = table(series)
    mafdict = {}
    for k in t:
        newk = '%.10f' % k
        if not newk in mafdict:
            mafdict[newk] = t[k]
        else:
            mafdict[newk] += t[k]
    if count is False:
        # if I want proportions
        rets = OrderedDict()
        for newk, count in mafdict.items():
            rets[newk] = count / sum(mafdict.values())
        mafdict = rets
    return mafdict

def subcategorybar(X, vals, width=.9):
    n = len(vals)
    _X = np.arange(len(X))
    for i in range(n):
        plt.bar(_X - width/2. + i/float(n)*width, vals[i], 
                width=width/float(n), align="edge")   
    plt.xticks(_X, X)

def make_mafdict_fig(pruned_snpdict, all_snpdict, title=None):
    fig = plt.figure(figsize=(25,5))
    X = ['%.3f' % float(key) for key in sorted(keys(pruned_snpdict))]
    Y = [pruned_snpdict[freq] for freq in sorted(keys(pruned_snpdict))]
    Z = [all_snpdict[freq] for freq in sorted(keys(all_snpdict))]
    subcategorybar(X, [Y,Z])
    plt.legend(['filtered snps', 'all snps'],fontsize=20)
    plt.ylabel('proportion of SNPs in category',size=20)
    plt.xlabel('minor allele frequency',size=20)
    plt.title(title, size=20)
    plt.show()

def get_skipto_df(f, skipto, nrows, cols=None, filter_maf=False, **kwargs):
    """Retrieve dataframe in parallel so that all rows are captured when iterating.
    
    f = filename to open
    skipto = row number to skip, read rows thereafter
    nrows = how many rows to read from f after skipto
    """
    import pandas
    
    if skipto == 0:
        df = pandas.read_table(f, nrows=nrows-1)
    else:
        df = pandas.read_table(f, skiprows=range(1, skipto), nrows=nrows)
    
    if cols is not None:
        if isinstance(cols, str):
            cols = [cols]
        df = df[cols].copy()
    
    if filter_maf is True:
        return maf_filter(df, **kwargs)
    
    return df
dview['get_skipto_df'] = get_skipto_df

def filter_depth(*args):
    """Filter min/max depth, reduce columns."""
    chunk = get_skipto_df(*args)
    dpcols = [col for col in chunk.columns if '.DP' in col]
    freqcols = [col for col in chunk.columns if '.FREQ' in col]
    cols = ['CHROM', 'locus', 'AF', 'MAF'] + dpcols + freqcols
    chunk = chunk[cols].copy()
    for col in dpcols:
        chunk = chunk[chunk[col] >= 20].copy()
        chunk = chunk[chunk[col] < 1000].copy()
    chunk.index = chunk['locus'].tolist()
    return chunk

# %%
snpdir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI'

# %%
# get linenums for each variety and each type
linenums = {}
for f in fs(snpdir, pattern='SNP', dirs=False):
    out = !wc -l $f
    linenums[f] = int(out[0].split()[0])-1
    print(op.basename(f), linenums[f])
# Out:
# DF_pooled-varscan_all_bedfiles_SNP_FDI_maf_RD-recalculated.txt 2609583

# %%
# filter for depth in parallel as I read it in
f = keys(linenums)[0]
nrows = 50000
jobs = []
for skipto in range(0, linenums[f], nrows):
    jobs.append(lview.apply_async(filter_depth, *(f, skipto, nrows)))
watch_async(jobs)
# Out:
# 53
# 53

# %%
# combine depth-filtered chunks into one df
snps = pd.concat([j.r for j in jobs])
print(snps.shape)
snps.head()

# %%
luni(snps['CHROM'])
# Out:
# 27148

# %% [markdown]
# #### reduce those snps on contigs > 1Kbp

# %%
# get contig lengths
lengths = pd.read_table('/data/database/DouglasFir_ref_genome/DF_ref_edit.fasta.length', header=None)
lengths.head()
# Out:
#                   0       1
# 0  jcf7190000000000  104664
# 1  jcf7190000000004  713351
# 2  jcf7190000000008  780568
# 3  jcf7190000000009   80234
# 4  jcf7190000000010  335878

# %%
lens = dict((contig,length) for (contig,length) in zip(lengths[0],lengths[1]) if length>1000)
len(lens.keys())
# Out:
# 79910

# %%
freqcols = [col for col in snps.columns if '.FREQ' in col]
reduced = snps[snps['CHROM'].isin(list(lens.keys()))].copy()
reduced = reduced.loc[:, freqcols + ['CHROM', 'AF', 'MAF']]
reduced.shape, snps.shape
# Out:
# ((1216986, 45), (1219501, 88))

# %%
len(freqcols)
# Out:
# 42

# %%
min(lens.values())
# Out:
# 1001

# %%
# compare MAF spectrum between depth-filtered and precursor
make_mafdict_fig(get_mafdict(reduced['AF'], roundto=2),
                 get_mafdict(snps['AF'], roundto=2),
                 title='Doug fir interior\nafter filtering for contig length >1Kbp')
# Out:
# 46
# 46

# %% [markdown]
# #### reduce to no missing data
#
# Turns out I can't filter for no missing data, the MAF spectrum doesn't match well with MAF spectrum of all data. Filter instead for % missing below.

# %%
# def reduce_col(col):
#     """Return list of loci with no missing data for pop.FREQ col."""
#     return reduced[~reduced[col].isnull()].index

# %%
# # get loci from each pop without missing data
# reduce_col_outs = []
# for col in nb(freqcols):
#     reduce_col_outs.append(reduce_col(col))
# Out:
# 100%|██████████| 42/42 [00:32<00:00,  1.29it/s]

# %%
# # combine returns to get loci with no missing data across pop.FREQ cols
# nomissingloci = snps.index.tolist()
# for out in nb(reduce_col_outs):
#     nomissingloci = list(set(nomissingloci).intersection(out))
# len(nomissingloci), luni(nomissingloci)
# Out:
# 100%|██████████| 42/42 [00:16<00:00,  2.59it/s]
# (370749, 370749)

# %%
# # reduce snp table to no missing loci
# reduced_nm = reduced[reduced.index.isin(nomissingloci)]
# reduced_nm.head()
# Out:
#                         DF_p18.FREQ DF_p19.FREQ DF_p20.FREQ DF_p3.FREQ  \
# jcf7190000000004-54643       32.14%      12.28%      25.93%     42.86%
# jcf7190000000004-54644        80.7%      96.55%      84.62%     90.32%
# jcf7190000000004-54700        87.5%      96.72%      85.29%     88.68%
# jcf7190000000004-55345       89.83%      95.71%      86.67%     91.18%
# jcf7190000000004-289701      61.64%      83.33%      79.41%     83.33%
#
#                         DF_p33.FREQ DF_p34.FREQ DF_p35.FREQ DF_p36.FREQ  \
# jcf7190000000004-54643       36.36%      28.57%      25.86%      42.19%
# jcf7190000000004-54644       92.54%      89.47%         90%      77.78%
# jcf7190000000004-54700       89.86%      88.73%      85.29%      86.67%
# jcf7190000000004-55345       92.31%      89.47%         92%      77.78%
# jcf7190000000004-289701      86.13%      67.71%      78.26%      66.27%
#
#                         DF_p37.FREQ DF_p38.FREQ DF_p39.FREQ DF_p4.FREQ  \
# jcf7190000000004-54643       48.48%      26.32%      30.95%     55.56%
# jcf7190000000004-54644        87.5%      92.31%      90.48%     90.48%
# jcf7190000000004-54700       92.31%      94.12%       87.5%     92.06%
# jcf7190000000004-55345       88.89%      94.23%      88.89%     79.41%
# jcf7190000000004-289701      90.48%      85.51%      76.71%     69.03%
#
#                         DF_p40.FREQ DF_p41.FREQ DF_p42.FREQ DF_p43.FREQ  \
# jcf7190000000004-54643       29.63%      31.43%      54.17%      35.82%
# jcf7190000000004-54644       76.92%      73.53%      83.33%      83.58%
# jcf7190000000004-54700       80.77%      74.29%      71.43%      81.67%
# jcf7190000000004-55345          80%      71.05%       87.5%      78.43%
# jcf7190000000004-289701      71.88%       87.1%      78.57%      65.12%
#
#                         DF_p44.FREQ DF_p45.FREQ DF_p46.FREQ DF_p47.FREQ  \
# jcf7190000000004-54643        30.3%      23.21%      47.46%      35.59%
# jcf7190000000004-54644       68.25%      77.78%      86.44%      82.14%
# jcf7190000000004-54700       80.77%      77.59%      86.36%      82.54%
# jcf7190000000004-55345       86.11%      75.41%      76.74%      82.46%
# jcf7190000000004-289701      64.35%      66.35%      72.86%      84.35%
#
#                         DF_p48.FREQ DF_p49.FREQ DF_p5.FREQ DF_p54.FREQ  \
# jcf7190000000004-54643       15.38%      31.37%       8.7%         25%
# jcf7190000000004-54644       53.85%      78.85%     75.56%        100%
# jcf7190000000004-54700       52.38%      80.36%     68.89%        100%
# jcf7190000000004-55345       55.36%       79.1%        70%        100%
# jcf7190000000004-289701      49.18%       69.5%     69.62%      86.11%
#
#                         DF_p55.FREQ DF_p56.FREQ DF_p57.FREQ DF_p58.FREQ  \
# jcf7190000000004-54643       16.13%      26.32%      39.29%      16.44%
# jcf7190000000004-54644       90.16%      83.33%      84.62%      85.14%
# jcf7190000000004-54700       90.41%      83.75%      78.43%      87.67%
# jcf7190000000004-55345       87.93%      89.61%       80.3%      85.54%
# jcf7190000000004-289701      68.97%      75.45%      64.22%       58.7%
#
#                         DF_p59.FREQ DF_p6.FREQ DF_p60.FREQ DF_p61.FREQ  \
# jcf7190000000004-54643       32.56%     14.29%      13.33%      16.33%
# jcf7190000000004-54644       83.72%     34.48%      95.95%      81.63%
# jcf7190000000004-54700       83.33%     37.74%       91.3%      75.86%
# jcf7190000000004-55345       86.49%     22.97%      93.51%      74.29%
# jcf7190000000004-289701       79.1%     32.35%      79.22%      68.32%
#
#                         DF_p62.FREQ DF_p7.FREQ DF_p8.FREQ DF_p85.FREQ  \
# jcf7190000000004-54643        41.1%     35.38%     58.14%      34.21%
# jcf7190000000004-54644       86.11%      69.7%     78.57%      95.95%
# jcf7190000000004-54700       84.62%     72.58%     80.56%      94.74%
# jcf7190000000004-55345       87.84%        75%     81.58%      82.89%
# jcf7190000000004-289701      85.91%     68.75%     86.42%      72.41%
#
#                         DF_p86.FREQ DF_p87.FREQ DF_p88.FREQ DF_p89.FREQ  \
# jcf7190000000004-54643       29.55%      15.09%       37.5%      21.05%
# jcf7190000000004-54644       82.22%      90.57%      58.82%      77.19%
# jcf7190000000004-54700       76.79%      88.14%      55.88%      77.08%
# jcf7190000000004-55345       90.24%      79.07%       52.5%      80.43%
# jcf7190000000004-289701      72.48%      71.13%      60.22%      66.07%
#
#                         DF_p9.FREQ DF_p94.FREQ             CHROM        AF  \
# jcf7190000000004-54643      42.86%        8.7%  jcf7190000000004  0.303347
# jcf7190000000004-54644         75%         80%  jcf7190000000004  0.817361
# jcf7190000000004-54700      77.19%      75.47%  jcf7190000000004  0.814210
# jcf7190000000004-55345         68%      78.72%  jcf7190000000004  0.809950
# jcf7190000000004-289701     69.86%      65.69%  jcf7190000000004  0.722703
#
#                               MAF
# jcf7190000000004-54643   0.303347
# jcf7190000000004-54644   0.182639
# jcf7190000000004-54700   0.185790
# jcf7190000000004-55345   0.190050
# jcf7190000000004-289701  0.277297

# %%
# # compare MAF spectrum between no-missing and precursor
# make_mafdict_fig(get_mafdict(reduced_nm['AF'], roundto=2),
#                  get_mafdict(snps['AF'], roundto=2),
#                  title='Doug fir interior\nafter filtering for no missing data')
# Out:
# 46
# 46

# %% [markdown]
# #### try to reduce to X% missing data ...
#
# Result: any filtering resulted in a visibly different MAF spectrum

# %%
def filter_perc(df, perc=0.10):
    """Filter df for missing data below perc."""
    import pandas
    from tqdm.notebook import tqdm as tnb
    
    freqcols = [col for col in df.columns if '.FREQ' in col]
    keep = []
    for locus in tnb(df.index):
        if sum(df.loc[locus,:].isnull())/len(freqcols) <= perc:
            keep.append(locus)
    return keep

# %%
jobs = []
tosend = []
i = 0
for locus in tnb(reduced.index):
    tosend.append(locus)
    if len(tosend) == 21732 or (i+1)==nrow(reduced):
#         jobs.append(lview.apply_async(filter_perc, reduced.loc[tosend, :]))
        jobs.append(lview.apply_async(filter_perc, reduced.loc[tosend, :], **{'perc':0.2}))
        tosend = []
    i += 1
watch_async(jobs)
# Out:
# 56
# 56

# %%
perc_loci = []
for j in jobs:
    perc_loci.extend(j.r)
len(perc_loci)
# Out:
# 1158566

# %%
# compare MAF spectrum between no-missing and precursor
make_mafdict_fig(get_mafdict(reduced.loc[perc_loci, 'AF'], roundto=2),
                 get_mafdict(snps['AF'], roundto=2),
                 title='Doug fir interior\nafter filtering for <10% missing data')
# Out:
# 46
# 46

# %%
# compare MAF spectrum between no-missing and precursor
# MIGHT AS WELL KEEP LOCI WITHOUT FILTERING FOR MISSING DATA
make_mafdict_fig(get_mafdict(reduced.loc[perc_loci, 'AF'], roundto=2),
                 get_mafdict(snps['AF'], roundto=2),
                 title='Doug fir interior\nafter filtering for <20% missing data')
# Out:
# 46
# 46

# %% [markdown]
# <center> SETTING PERC TO 0.25 MEANS NO LOCI WERE FILTERED BY MAF
#
#     if I tried filtering < 25% missing data, the MAF spectrum looked weird, leaving the code inplace.

# %% [markdown]
# #### choose one snp per contig at random

# %%
len(lview)
# Out:
# 56

# %%
def choose_random_loci(df):
    """For each chrom in df['CHROM'], randomly choose 1 snp."""
    import pandas
    import random

    keep = []
    for chrom in uni(df['CHROM']):
        loci = df.loc[chrom, 'locus']
        if isinstance(loci, str):
            keep.append(loci)
            continue
        loci = loci.tolist()
        random.shuffle(loci)
        keep.append(loci[0])
    return keep
        
dview['uni'] = uni

# %%
# how many chroms do I send to a job? A: math.ceil(476.42)
luni(reduced['CHROM']), luni(reduced['CHROM'])/len(lview)
# Out:
# (26680, 476.42857142857144)

# %%
# change the index for easy sending
reduced['locus'] = reduced.index.tolist()
reduced.index = reduced['CHROM'].tolist()

# %%
nrow(reduced), luni(reduced['locus'])
# Out:
# (1216986, 1216986)

# %%
# choose random loci in parallel
jobs = []
tosend = []
i = 0
numchroms = luni(reduced['CHROM'])
for chrom in tnb(uni(reduced['CHROM'])):
    tosend.append(chrom)
    if len(tosend) == 477 or (i+1)==numchroms:
        jobs.append(lview.apply_async(choose_random_loci, reduced.loc[tosend, :]))
        tosend = []
    i += 1
watch_async(jobs)
# Out:
# 56
# 56

# %%
# get returns from jobs
randomloci = []
for j in jobs:
    randomloci.extend(j.r)
len(randomloci) == luni(reduced['CHROM'])
# Out:
# True

# %%
# reset index, reduce reduced to only randomloci
red = reduced[reduced['locus'].isin(randomloci)].copy()
print(nrow(red), len(randomloci))
red.head()
# Out:
# 26680 26680
#                  DF_p18.FREQ DF_p19.FREQ DF_p20.FREQ DF_p3.FREQ DF_p33.FREQ  \
# jcf7190000000004       4.94%      18.18%       8.33%        NaN      11.11%
# jcf7190000000008      17.95%      17.39%         NaN     30.56%       9.52%
# jcf7190000000011       7.64%      11.51%      10.59%      9.12%      10.66%
# jcf7190000000014        100%        100%      98.51%       100%        100%
# jcf7190000000023       3.33%       5.63%       7.89%        15%         NaN
#
#                  DF_p34.FREQ DF_p35.FREQ DF_p36.FREQ DF_p37.FREQ DF_p38.FREQ  \
# jcf7190000000004      16.67%        9.9%      10.71%       7.55%       4.82%
# jcf7190000000008      31.11%      22.86%      11.11%         NaN         60%
# jcf7190000000011      11.33%      10.06%      12.03%        9.5%      10.98%
# jcf7190000000014      98.85%       58.9%          0%        100%        100%
# jcf7190000000023      14.29%       7.27%       7.89%       5.88%       6.06%
#
#                  DF_p39.FREQ DF_p4.FREQ DF_p40.FREQ DF_p41.FREQ DF_p42.FREQ  \
# jcf7190000000004       4.69%      6.72%         28%         NaN      22.22%
# jcf7190000000008      29.63%     16.98%      17.07%      21.21%       9.52%
# jcf7190000000011      11.82%     10.09%      10.32%       8.03%      11.23%
# jcf7190000000014      10.39%         0%       3.17%      65.22%      78.26%
# jcf7190000000023       9.09%      4.17%         NaN         NaN      13.79%
#
#                  DF_p43.FREQ DF_p44.FREQ DF_p45.FREQ DF_p46.FREQ DF_p47.FREQ  \
# jcf7190000000004      16.87%       5.34%         18%       9.72%      14.17%
# jcf7190000000008      28.21%      31.91%      42.42%      22.22%       30.3%
# jcf7190000000011       7.79%      12.86%       8.33%      11.81%      10.67%
# jcf7190000000014          0%          0%      34.34%        100%        100%
# jcf7190000000023       7.14%       6.98%      13.33%      10.26%      22.45%
#
#                  DF_p48.FREQ DF_p49.FREQ DF_p5.FREQ DF_p54.FREQ DF_p55.FREQ  \
# jcf7190000000004       1.55%      15.97%        NaN      12.93%       3.54%
# jcf7190000000008      21.82%      22.73%     31.58%      17.31%       7.69%
# jcf7190000000011       8.84%      12.16%     13.99%      11.35%      11.49%
# jcf7190000000014        100%          0%     97.59%        100%        100%
# jcf7190000000023        9.3%       8.16%     10.29%         20%      15.56%
#
#                  DF_p56.FREQ DF_p57.FREQ DF_p58.FREQ DF_p59.FREQ DF_p6.FREQ  \
# jcf7190000000004       6.84%      11.32%       2.48%       1.49%      0.99%
# jcf7190000000008      40.62%         34%      27.08%      35.48%        28%
# jcf7190000000011      12.85%      11.03%      12.01%      13.21%      6.04%
# jcf7190000000014        100%        100%        100%        100%         0%
# jcf7190000000023         NaN      10.45%         NaN       8.51%      6.25%
#
#                  DF_p60.FREQ DF_p61.FREQ DF_p62.FREQ DF_p7.FREQ DF_p8.FREQ  \
# jcf7190000000004      22.98%       8.04%        0.8%        NaN        NaN
# jcf7190000000008      18.37%      48.08%      31.58%     14.29%     24.24%
# jcf7190000000011      13.35%      11.98%      12.01%     11.85%     11.21%
# jcf7190000000014        100%        100%      97.14%     66.13%       100%
# jcf7190000000023       5.45%      14.08%         NaN     17.74%      9.38%
#
#                  DF_p85.FREQ DF_p86.FREQ DF_p87.FREQ DF_p88.FREQ DF_p89.FREQ  \
# jcf7190000000004       7.84%       2.59%       7.14%         NaN         NaN
# jcf7190000000008         36%      32.73%       22.5%         20%      37.04%
# jcf7190000000011      12.21%       8.45%      14.03%       9.97%      10.93%
# jcf7190000000014      78.47%      40.85%      71.43%      79.63%      58.62%
# jcf7190000000023      13.79%       6.82%      34.29%         NaN         NaN
#
#                  DF_p9.FREQ DF_p94.FREQ             CHROM        AF       MAF  \
# jcf7190000000004         5%      10.31%  jcf7190000000004  0.097246  0.097246
# jcf7190000000008     26.09%      34.78%  jcf7190000000008  0.265446  0.265446
# jcf7190000000011      7.55%       6.91%  jcf7190000000011  0.107023  0.107023
# jcf7190000000014      62.5%        100%  jcf7190000000014  0.711719  0.288281
# jcf7190000000023      6.45%         NaN  jcf7190000000023  0.107936  0.107936
#
#                                     locus
# jcf7190000000004  jcf7190000000004-289808
# jcf7190000000008  jcf7190000000008-431360
# jcf7190000000011  jcf7190000000011-190688
# jcf7190000000014   jcf7190000000014-15050
# jcf7190000000023   jcf7190000000023-30076

# %%
# reset index
reduced = red.copy()
reduced.index = reduced['locus'].tolist()
reduced.shape
# Out:
# (26680, 46)

# %%
make_mafdict_fig(get_mafdict(reduced['AF'], roundto=2),
                 get_mafdict(snps['AF'], roundto=2),
                 title='Doug fir\nafter choose one SNP per contig for contigs > 1Kb')
# Out:
# 46
# 46

# %% [markdown]
# #### get an idea of r2 values so we can determine an empirical high-end cutoff

# %%
len(lview)
# Out:
# 56

# %%
def getfreqs(myloci):
    """Get the population ALT frequency as a float (reported as a str in table).
    
    Returns
    -------
    list of tuples
        - first element = locus name
        - second element = pandas.Series
    """
    rets = []
    for locus in myloci:
        rets.append((locus, reduced.loc[locus, freqcols].str.replace("%", "").astype(float) / 100))
    return rets
dview['getfreqs'] = getfreqs
dview['freqcols'] = freqcols
dview['reduced'] = reduced[freqcols]

def getr2(myloci):
    from scipy.stats import pearsonr
    from numpy import logical_or
    from tqdm.notebook import tqdm as nb

    freqs = dict((locus, freqs) for (locus,freqs) in getfreqs(myloci))

    r2vals = []
    i = 0
    for locusi in nb(myloci):
        for j,locusj in enumerate(myloci):
            if i < j:
                nas = logical_or(freqs[locusi].isnull(), freqs[locusj].isnull())
                r2 = pearsonr(freqs[locusi][~nas], freqs[locusj][~nas])[0]**2
                r2vals.append(r2)
        i += 1
    return r2vals

# %%
jobs = send_chunks(getr2, randomloci, 240, lview)
watch_async(jobs)
# Out:
# 112
# 112

# %%
r2vals = []
for j in jobs:
    r2vals.extend(j.r)
plt.hist(r2vals, bins=100)
plt.show()

# %%
# what is 99.99th percentile?
sorted(r2vals)[math.ceil(len(r2vals)*.9999)]
# Out:
# 0.7045941368215466

# %%
# get 99.9th percentile
sorted(r2vals)[math.ceil(len(r2vals)*.999)]
# Out:
# 0.5642448902244581

# %%
# what is 99th percentile?
sorted(r2vals)[math.ceil(len(r2vals)*.99)]
# Out:
# 0.3875596557874945

# %%
# what is 98th percentile?
sorted(r2vals)[math.ceil(len(r2vals)*.98)]
# Out:
# 0.3247159221595135

# %%
# what is 97th percentile?
sorted(r2vals)[math.ceil(len(r2vals)*.97)]
# Out:
# 0.2866305675733651

# %%
# what perc is 0.2
for i,x in enumerate(sorted(r2vals)):
    if x > 0.2:
        print(i)
        break
(i+1)/len(r2vals)
# Out:
# 3071270
# 0.9263763211234979

# %%
# what perc is 0.3
for i,x in enumerate(sorted(r2vals)):
    if x > 0.3:
        print(i)
        break
(i+1)/len(r2vals)
# Out:
# 3229028
# 0.9739602939047344

# %%
# what perc is 0.3606818877742702 (to compare with jack pine)
for i,x in enumerate(sorted(r2vals)):
    if x > 0.3606818877742702:
        print(i)
        break
(i+1)/len(r2vals)
# Out:
# 3270449
# 0.9864539597509773

# %%
# use 98th percentile
r2thresh = 0.3247

# %% [markdown]
# #### LD prune random loci¶

# %%
reduced.shape
# Out:
# (26680, 46)

# %%
len(randomloci)
# Out:
# 26680

# %%
snps.shape, reduced.shape
# Out:
# ((1219501, 88), (26680, 46))

# %%
len(freqcols)
# Out:
# 42

# %%
freqs = dict((locus, freqs) for (locus,freqs) in getfreqs(randomloci))
dview['freqs'] = freqs
dview['reduced'] = None
len(freqs)
# Out:
# 26680

# %%
def prune_em(compareto, locusi=None, r2thresh=0.2):
    from scipy.stats import pearsonr
    from numpy import logical_or
    
    drop = []
    for locusj in compareto:
        nas = logical_or(freqs[locusi].isnull(), freqs[locusj].isnull())
        r2 = pearsonr(freqs[locusi][~nas], freqs[locusj][~nas])[0]**2
#         print('r2 = ', r2)
        if r2 > r2thresh:
            drop.append(locusj)

    return locusi,drop

# %%
r2thresh
# Out:
# 0.3247

# %%
# send locus along with all needed loci for pairwise comparisons to engines
# each locus (job) has r2 calculated for each of the remaining unique pairwise combinations
# so the first job compares locus1 to locus2-locusn, second job locus2 to locus3-locusn ... 
jobs = []
i = 0
for locusi in tnb(randomloci):
    tosend = randomloci[i+1:]
    jobs.append(lview.apply_async(prune_em, tosend, **{'r2thresh':r2thresh, 'locusi':locusi}))
    i += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=26680.0), HTML(value='')))

# %%
# iterate jobs, if finished jobs are an unbroken sequenced 0:(n-1), check returns and cancel any loci iterations
    # downstream. eg if locus0 has r2 > r2thresh with locus100, drop locus100 and kill jobs[100] to save some time

# found = {-1: None}  # comment this out after running this the first time in case I want to interrupt and restart
# keep = list(randomloci)  # comment this out after running this the first time in case I want to interrupt and restart
maxx = -1
while maxx < (len(randomloci) - 1):
    i = 0  # jcount
    for j in tnb(jobs):
        if j.ready() and i-1 in found.keys() and i not in found.keys():
            found[i] = True
            try:
                locusi, drop = j.r
            except: # CancelledError
                continue
            if locusi in keep:
                for locusj in drop:
                    if locusj in keep:
                        job_idx = randomloci.index(locusj)
    #                     print('\tcanceling ', job_idx, '. ', locusj, randomloci[job_idx])
                        jobs[job_idx].cancel()
                        keep.remove(locusj)
        i += 1
    maxx = max(found.keys())
    if maxx+1 < len(randomloci):
        update([(jobs[maxx+1].ready(), maxx, len(found.keys()), len(keep))])
        time.sleep(10)
len(keep)
# Out:
# (False, 26166, 26168, 4295)
# HBox(children=(FloatProgress(value=0.0, max=26680.0), HTML(value='')))
# 4295

# %%
# combined varieties had 3591 ld-pruned loci
baydir = makedir(op.join(snpdir, 'baypass'))
pkl = op.join(baydir, 'lessthan25perc-missing-data_20-dp-1000_random-snps_1-per-contig-gt1Kbp_r2-lessthan-p3247.pkl')
pkldump(keep, pkl)

# %%
op.exists(op.join(baydir, 'lessthan25perc-missing-data_20-dp-1000_random-snps_1-per-contig-gt1Kbp_r2-lessthan-p3247.pkl'))
# Out:
# True

# %%
# compare MAF spectrum between rdpruned and precursor
make_mafdict_fig(get_mafdict(reduced['AF'], roundto=2),
                 get_mafdict(snps['AF'], roundto=2),
                 title='Doug fir interior\nafter LD pruning filtered SNPs')
# Out:
# 46
# 46

# %%
baydir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass'

# %% [markdown]
# # create infiles to baypass to estimate neutral structure
#
# #### <center> genotyping data
#
# "The genotyping data file is simply organized as a matrix with
# nsnp rows and 2 ∗ npop columns. The row field separator is a space. More
# precisely, each row corresponds to one marker and the number of columns is
# twice the number of populations because each pair of numbers corresponds to
# each allele (or read counts for PoolSeq experiment) counts in one population"

# %%
lview,dview = get_client()
# Out:
# 56 56

# %%
baydir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass'

# %%
fs(baydir, bnames=True, dirs=False)
# Out:
# ['lessthan25perc-missing-data_20-dp-1000_random-snps_1-per-contig-gt1Kbp_r2-lessthan-p3247.pkl']

# %%
prunedloci = pklload(op.join(baydir, 'lessthan25perc-missing-data_20-dp-1000_random-snps_1-per-contig-gt1Kbp_r2-lessthan-p3247.pkl'))
len(prunedloci)
# Out:
# 4295

# %%
linenums
# Out:
# {'/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/DF_pooled-varscan_all_bedfiles_SNP_FDI_maf_RD-recalculated.txt': 2609583}

# %%
# read in snps in parallel
f = keys(linenums)[0]
nrows = 10000
jobs = []
for skipto in range(0, linenums[f], nrows):
    jobs.append(lview.apply_async(get_skipto_df, *(f, skipto, nrows)))
watch_async(jobs)
# Out:
# 261
# 261

# %%
# get the returns, reduce to pruned loci
snps = pd.concat([j.r for j in jobs])
snps.index = snps['locus'].tolist()
reduced = snps[snps['locus'].isin(prunedloci)].copy()
print(reduced.shape)
reduced.head()
# Out:
# (4295, 351)
#                                     CHROM     POS REF ALT        AF  QUAL  \
# jcf7190000000008-431360  jcf7190000000008  431360   G   A  0.265446 -10.0
# jcf7190000000056-6513    jcf7190000000056    6513   C   T  0.347619 -10.0
# jcf7190000000070-125991  jcf7190000000070  125991   G   C  0.053856 -10.0
# jcf7190000000084-68476   jcf7190000000084   68476   C   A  0.218836 -10.0
# jcf7190000000090-26387   jcf7190000000090   26387   T   A  0.520637 -10.0
#
#                         TYPE FILTER  ADP  WT  HET  HOM  NC DF_p18.GT  \
# jcf7190000000008-431360  SNP   PASS   52   8   79    0   0       G/A
# jcf7190000000056-6513    SNP   PASS   36   4   83    0   0       C/C
# jcf7190000000070-125991  SNP   PASS   97  57   30    0   0       G/C
# jcf7190000000084-68476   SNP   PASS   62   7   80    0   0       C/A
# jcf7190000000090-26387   SNP   PASS  107   0   86    1   0       T/A
#
#                          DF_p18.GQ  DF_p18.SDP  DF_p18.DP DF_p18.FREQ  \
# jcf7190000000008-431360       22.0          39       39.0      17.95%
# jcf7190000000056-6513         35.0          35       35.0      11.43%
# jcf7190000000070-125991       18.0         113      113.0         NaN
# jcf7190000000084-68476        25.0          61       61.0      13.11%
# jcf7190000000090-26387       154.0          89       89.0      47.19%
#
#                           DF_p18.PVAL  DF_p18.AD  DF_p18.RD DF_p19.GT  \
# jcf7190000000008-431360  5.821900e-03        7.0       32.0       G/A
# jcf7190000000056-6513    5.710600e-02        4.0       31.0       C/T
# jcf7190000000070-125991  1.459700e-02        6.0      107.0       G/C
# jcf7190000000084-68476   3.045000e-03        8.0       53.0       C/A
# jcf7190000000090-26387   3.745800e-16       42.0       47.0       T/A
#
#                          DF_p19.GQ  DF_p19.SDP  DF_p19.DP DF_p19.FREQ  \
# jcf7190000000008-431360       25.0          46       46.0      17.39%
# jcf7190000000056-6513         72.0          44       44.0      45.45%
# jcf7190000000070-125991       24.0         142      142.0       5.63%
# jcf7190000000084-68476       106.0          97       97.0      31.96%
# jcf7190000000090-26387       255.0         195      195.0      38.97%
#
#                           DF_p19.PVAL  DF_p19.AD  DF_p19.RD DF_p20.GT  \
# jcf7190000000008-431360  2.803300e-03        8.0       38.0       G/G
# jcf7190000000056-6513    5.728600e-08       20.0       24.0       C/T
# jcf7190000000070-125991  3.530000e-03        8.0      134.0       G/C
# jcf7190000000084-68476   2.478200e-11       31.0       66.0       C/C
# jcf7190000000090-26387   1.404300e-27       76.0      119.0       T/A
#
#                          DF_p20.GQ  DF_p20.SDP  DF_p20.DP DF_p20.FREQ  \
# jcf7190000000008-431360       19.0          21       21.0         NaN
# jcf7190000000056-6513         39.0          24       24.0      45.83%
# jcf7190000000070-125991       15.0          51       51.0         NaN
# jcf7190000000084-68476        38.0          26       26.0       3.85%
# jcf7190000000090-26387       255.0          83       83.0       74.7%
#
#                           DF_p20.PVAL  DF_p20.AD  DF_p20.RD DF_p3.GT  \
# jcf7190000000008-431360  1.158500e-01        3.0       18.0      G/A
# jcf7190000000056-6513    1.104700e-04       11.0       13.0      C/T
# jcf7190000000070-125991  2.820300e-02        5.0       46.0      G/G
# jcf7190000000084-68476   5.000000e-01        1.0       25.0      C/A
# jcf7190000000090-26387   8.833600e-28       62.0       21.0      T/A
#
#                          DF_p3.GQ  DF_p3.SDP  DF_p3.DP DF_p3.FREQ  \
# jcf7190000000008-431360      37.0         36      36.0     30.56%
# jcf7190000000056-6513        41.0         34      34.0     35.29%
# jcf7190000000070-125991     158.0        106     106.0      2.83%
# jcf7190000000084-68476       67.0         73      73.0      27.4%
# jcf7190000000090-26387      250.0         79      79.0     73.42%
#
#                            DF_p3.PVAL  DF_p3.AD  DF_p3.RD DF_p33.GT  \
# jcf7190000000008-431360  1.987900e-04      11.0      25.0       G/G
# jcf7190000000056-6513    7.530200e-05      12.0      22.0       C/T
# jcf7190000000070-125991  1.232200e-01       3.0     103.0       G/G
# jcf7190000000084-68476   1.905000e-07      20.0      53.0       C/A
# jcf7190000000090-26387   8.817800e-26      58.0      21.0       T/A
#
#                          DF_p33.GQ  DF_p33.SDP  DF_p33.DP DF_p33.FREQ  ...  \
# jcf7190000000008-431360       43.0          42       42.0       9.52%  ...
# jcf7190000000056-6513         44.0          41       41.0      31.71%  ...
# jcf7190000000070-125991      159.0         112      112.0       3.57%  ...
# jcf7190000000084-68476        48.0          72       72.0      20.83%  ...
# jcf7190000000090-26387       181.0         111      111.0      45.05%  ...
#
#                          DF_p86.GT  DF_p86.GQ  DF_p86.SDP DF_p86.DP  \
# jcf7190000000008-431360        G/A       61.0          55      55.0
# jcf7190000000056-6513          C/T       33.0          35      35.0
# jcf7190000000070-125991        G/G      164.0          88      88.0
# jcf7190000000084-68476         C/A       46.0          50      50.0
# jcf7190000000090-26387         T/A      109.0          65      65.0
#
#                          DF_p86.FREQ   DF_p86.PVAL  DF_p86.AD DF_p86.RD  \
# jcf7190000000008-431360       32.73%  7.224200e-07       18.0      37.0
# jcf7190000000056-6513         28.57%  4.627600e-04       10.0      25.0
# jcf7190000000070-125991           0%  1.000000e+00        0.0      88.0
# jcf7190000000084-68476           28%  2.122400e-05       14.0      36.0
# jcf7190000000090-26387        46.15%  1.151900e-11       30.0      35.0
#
#                          DF_p87.GT  DF_p87.GQ  DF_p87.SDP DF_p87.DP  \
# jcf7190000000008-431360        G/A       29.0          40      40.0
# jcf7190000000056-6513          C/T       47.0          45      45.0
# jcf7190000000070-125991        G/G      152.0         107     107.0
# jcf7190000000084-68476         C/A       52.0          71      71.0
# jcf7190000000090-26387         T/A      201.0         108     108.0
#
#                          DF_p87.FREQ   DF_p87.PVAL  DF_p87.AD DF_p87.RD  \
# jcf7190000000008-431360        22.5%  1.179100e-03        9.0      31.0
# jcf7190000000056-6513         31.11%  1.846200e-05       14.0      31.0
# jcf7190000000070-125991        3.74%  6.074400e-02        4.0     103.0
# jcf7190000000084-68476        22.54%  5.805500e-06       16.0      55.0
# jcf7190000000090-26387           50%  7.041900e-21       54.0      54.0
#
#                          DF_p88.GT  DF_p88.GQ  DF_p88.SDP DF_p88.DP  \
# jcf7190000000008-431360        G/A       29.0          45      45.0
# jcf7190000000056-6513          C/T       39.0          44      44.0
# jcf7190000000070-125991        G/G      126.0          82      82.0
# jcf7190000000084-68476         C/A       42.0          60      60.0
# jcf7190000000090-26387         T/A      153.0          90      90.0
#
#                          DF_p88.FREQ   DF_p88.PVAL  DF_p88.AD DF_p88.RD  \
# jcf7190000000008-431360          20%  1.254700e-03        9.0      36.0
# jcf7190000000056-6513         27.27%  1.027000e-04       12.0      32.0
# jcf7190000000070-125991        2.44%  2.484700e-01        2.0      80.0
# jcf7190000000084-68476        21.67%  5.899100e-05       13.0      47.0
# jcf7190000000090-26387        46.67%  4.121200e-16       42.0      48.0
#
#                          DF_p89.GT  DF_p89.GQ  DF_p89.SDP DF_p89.DP  \
# jcf7190000000008-431360        G/A       34.0          27      27.0
# jcf7190000000056-6513          C/T       23.0          23      23.0
# jcf7190000000070-125991        G/G      128.0          94      94.0
# jcf7190000000084-68476         C/A       32.0          55      55.0
# jcf7190000000090-26387         T/A      201.0         131     131.0
#
#                          DF_p89.FREQ   DF_p89.PVAL  DF_p89.AD DF_p89.RD  \
# jcf7190000000008-431360       37.04%  3.525300e-04       10.0      17.0
# jcf7190000000056-6513         30.43%  4.580300e-03        7.0      16.0
# jcf7190000000070-125991        4.26%  6.050000e-02        4.0      90.0
# jcf7190000000084-68476        18.18%  6.180000e-04       10.0      45.0
# jcf7190000000090-26387        42.75%  7.300800e-21       56.0      75.0
#
#                          DF_p9.GT  DF_p9.GQ  DF_p9.SDP DF_p9.DP  DF_p9.FREQ  \
# jcf7190000000008-431360       G/A      39.0         46     46.0      26.09%
# jcf7190000000056-6513         C/T      39.0         46     46.0      26.09%
# jcf7190000000070-125991       G/G     138.0         93     93.0       3.23%
# jcf7190000000084-68476        C/A      56.0         66     66.0      25.76%
# jcf7190000000090-26387        T/A     164.0         65     65.0      63.08%
#
#                            DF_p9.PVAL  DF_p9.AD DF_p9.RD  DF_p94.GT  \
# jcf7190000000008-431360  1.072400e-04      12.0     34.0        G/A
# jcf7190000000056-6513    1.072400e-04      12.0     34.0        C/T
# jcf7190000000070-125991  1.229700e-01       3.0     90.0        G/C
# jcf7190000000084-68476   2.340800e-06      17.0     49.0        C/A
# jcf7190000000090-26387   3.393300e-17      41.0     24.0        T/A
#
#                          DF_p94.GQ  DF_p94.SDP DF_p94.DP  DF_p94.FREQ  \
# jcf7190000000008-431360       55.0          46      46.0       34.78%
# jcf7190000000056-6513         15.0          27      27.0          NaN
# jcf7190000000070-125991       21.0          90      90.0        7.78%
# jcf7190000000084-68476        39.0          53      53.0       22.64%
# jcf7190000000090-26387       101.0          79      79.0       36.71%
#
#                           DF_p94.PVAL  DF_p94.AD DF_p94.RD  \
# jcf7190000000008-431360  3.144600e-06       16.0      30.0
# jcf7190000000056-6513    2.552700e-02        5.0      22.0
# jcf7190000000070-125991  6.921700e-03        7.0      83.0
# jcf7190000000084-68476   1.193900e-04       12.0      41.0
# jcf7190000000090-26387   7.895400e-11       29.0      50.0
#
#                                            locus       MAF
# jcf7190000000008-431360  jcf7190000000008-431360  0.265446
# jcf7190000000056-6513      jcf7190000000056-6513  0.347619
# jcf7190000000070-125991  jcf7190000000070-125991  0.053856
# jcf7190000000084-68476    jcf7190000000084-68476  0.218836
# jcf7190000000090-26387    jcf7190000000090-26387  0.479363
#
# [5 rows x 351 columns]

# %%
len(set(prunedloci).intersection(reduced.index)) == len(prunedloci)
# Out:
# True

# %%
def get_counts(loci, numpops=0):
    """Create gfile for baypass.
    
    Get read counts for global major and minor allele. Missing data = 0."""
    import pandas
    from collections import OrderedDict
    import tqdm
    
    pops = [col.replace(".FREQ","") for col in reduced.columns if '.FREQ' in col]
#     assert len(pops) == numpops
    read_counts = OrderedDict()
    for locus in tqdm.tqdm_notebook(loci):
        if reduced.loc[locus, 'AF'] > 0.5:
            # this matches calculation of MAF from 001_JP_pooled_pangenome_data_explore.ipynb
            refismajor = False
            majortag = 'AD'
            minortag = 'RD'
        else:
            refismajor = True
            majortag = 'RD'
            minortag = 'AD'
        if refismajor is True:
#             print('checking ', locus)
            # double check that it matches MAF calculation
            assert reduced.loc[locus, 'AF'] == reduced.loc[locus, 'MAF']
        for pop in pops:
            for which,tag in zip(['major','minor'],[majortag, minortag]):
                newcol = "%s-%s" % (pop,which)
                if newcol not in read_counts:
                    read_counts[newcol] = OrderedDict()
                if reduced.loc[locus, f"{pop}.FREQ"] != reduced.loc[locus, f"{pop}.FREQ"]:
                    # if locus was filtered for this pop
                    read_counts[newcol][locus] = 0
                else:
                    try:
                        read_counts[newcol][locus] = int(reduced.loc[locus, "%s.%s" % (pop, tag)])
                    except ValueError as e:
                        # missing data - probably don't need this try statement when first looking at FREQ
                        read_counts[newcol][locus] = 0
    return pandas.DataFrame(read_counts)

# %%
# get the gfile using the prunedloci
neutral_read_counts = get_counts(prunedloci, numpops=42)
neutral_read_counts.head()
# Out:
# /data/programs/brandon_anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # Remove the CWD from sys.path while we load stuff.
# HBox(children=(FloatProgress(value=0.0, max=4295.0), HTML(value='')))
#                          DF_p18-major  DF_p18-minor  DF_p19-major  \
# jcf7190000004922-46795             72            22           105
# jcf7190000168302-2649             316            16           477
# jcf7190000243153-2724               0             0            67
# jcf7190000076552-2401               0             0            62
# jcf7190000266316-165308            82            10            93
#
#                          DF_p19-minor  DF_p20-major  DF_p20-minor  \
# jcf7190000004922-46795             25            64            15
# jcf7190000168302-2649              40           159            15
# jcf7190000243153-2724              11            19             9
# jcf7190000076552-2401              19            19             9
# jcf7190000266316-165308            14            40             6
#
#                          DF_p3-major  DF_p3-minor  DF_p33-major  DF_p33-minor  \
# jcf7190000004922-46795            93           23           103            13
# jcf7190000168302-2649            371           25           396            35
# jcf7190000243153-2724             39           14            33            11
# jcf7190000076552-2401              0            0            57            16
# jcf7190000266316-165308           92           10            75            40
#
#                          DF_p34-major  DF_p34-minor  DF_p35-major  \
# jcf7190000004922-46795             86            22           111
# jcf7190000168302-2649             368            24           400
# jcf7190000243153-2724              22             4            38
# jcf7190000076552-2401              60             8             0
# jcf7190000266316-165308            90            16            85
#
#                          DF_p35-minor  DF_p36-major  DF_p36-minor  \
# jcf7190000004922-46795             23            65            37
# jcf7190000168302-2649              41           264            20
# jcf7190000243153-2724              14            37            16
# jcf7190000076552-2401               0            63            11
# jcf7190000266316-165308            49            38            65
#
#                          DF_p37-major  DF_p37-minor  DF_p38-major  \
# jcf7190000004922-46795              0             0            51
# jcf7190000168302-2649             200            12           281
# jcf7190000243153-2724              18             8            37
# jcf7190000076552-2401               0             0            42
# jcf7190000266316-165308            35             5            76
#
#                          DF_p38-minor  DF_p39-major  DF_p39-minor  \
# jcf7190000004922-46795             13            49            17
# jcf7190000168302-2649              24           230            17
# jcf7190000243153-2724               7             0             0
# jcf7190000076552-2401               2            48             1
# jcf7190000266316-165308             9            59            35
#
#                          DF_p4-major  DF_p4-minor  DF_p40-major  DF_p40-minor  \
# jcf7190000004922-46795            97           20            36            10
# jcf7190000168302-2649            388           24           158            14
# jcf7190000243153-2724              0            0            27             8
# jcf7190000076552-2401             65           12            22             2
# jcf7190000266316-165308           56           62             8            27
#
#                          DF_p41-major  DF_p41-minor  DF_p42-major  \
# jcf7190000004922-46795             54            13            38
# jcf7190000168302-2649             211            19           177
# jcf7190000243153-2724              27            11            39
# jcf7190000076552-2401              27             2            33
# jcf7190000266316-165308            24            39            29
#
#                          DF_p42-minor  DF_p43-major  DF_p43-minor  \
# jcf7190000004922-46795              9            63            21
# jcf7190000168302-2649              17           292            20
# jcf7190000243153-2724               7             0             0
# jcf7190000076552-2401               3             0             0
# jcf7190000266316-165308            19            41            60
#
#                          DF_p44-major  DF_p44-minor  DF_p45-major  \
# jcf7190000004922-46795            118            29            67
# jcf7190000168302-2649             330            34           289
# jcf7190000243153-2724              25             4            41
# jcf7190000076552-2401              48            13            43
# jcf7190000266316-165308            99            37            56
#
#                          DF_p45-minor  DF_p46-major  DF_p46-minor  \
# jcf7190000004922-46795             13            71            22
# jcf7190000168302-2649              29           254            22
# jcf7190000243153-2724               7            31             8
# jcf7190000076552-2401               9            36             8
# jcf7190000266316-165308            53            64             8
#
#                          DF_p47-major  DF_p47-minor  DF_p48-major  \
# jcf7190000004922-46795            109            22            96
# jcf7190000168302-2649             384            23           418
# jcf7190000243153-2724               0             0            30
# jcf7190000076552-2401              41             3            56
# jcf7190000266316-165308            76            15            88
#
#                          DF_p48-minor  DF_p49-major  DF_p49-minor  \
# jcf7190000004922-46795             19           103            23
# jcf7190000168302-2649              35           339            31
# jcf7190000243153-2724               3            49             8
# jcf7190000076552-2401              10            65             7
# jcf7190000266316-165308            23            51            94
#
#                          DF_p5-major  DF_p5-minor  DF_p54-major  DF_p54-minor  \
# jcf7190000004922-46795            58           19           111            35
# jcf7190000168302-2649            303           29           436            31
# jcf7190000243153-2724             22           11            50            17
# jcf7190000076552-2401             48           17            75            26
# jcf7190000266316-165308           55            8           105            13
#
#                          DF_p55-major  DF_p55-minor  DF_p56-major  \
# jcf7190000004922-46795             91            25            93
# jcf7190000168302-2649             365            24           384
# jcf7190000243153-2724              32             7             0
# jcf7190000076552-2401              49            21            45
# jcf7190000266316-165308           107             1            76
#
#                          DF_p56-minor  DF_p57-major  DF_p57-minor  \
# jcf7190000004922-46795             37            96            32
# jcf7190000168302-2649              23           362            34
# jcf7190000243153-2724               0             0             0
# jcf7190000076552-2401              16            74             3
# jcf7190000266316-165308            21            86            32
#
#                          DF_p58-major  DF_p58-minor  DF_p59-major  \
# jcf7190000004922-46795            128            24            50
# jcf7190000168302-2649             387            33           260
# jcf7190000243153-2724              40             7            34
# jcf7190000076552-2401               0             0            35
# jcf7190000266316-165308           132             6            57
#
#                          DF_p59-minor  DF_p6-major  DF_p6-minor  DF_p60-major  \
# jcf7190000004922-46795             19           61           10           133
# jcf7190000168302-2649              23          383           22           400
# jcf7190000243153-2724               8           33            2            32
# jcf7190000076552-2401               3           84            0           102
# jcf7190000266316-165308            13            9          111           139
#
#                          DF_p60-minor  DF_p61-major  DF_p61-minor  \
# jcf7190000004922-46795             41           133            31
# jcf7190000168302-2649              32           446            34
# jcf7190000243153-2724               7            37            14
# jcf7190000076552-2401              13            48            12
# jcf7190000266316-165308             5            99            15
#
#                          DF_p62-major  DF_p62-minor  DF_p7-major  DF_p7-minor  \
# jcf7190000004922-46795            147            36          118           25
# jcf7190000168302-2649             394            31          407           28
# jcf7190000243153-2724              46             9           48           10
# jcf7190000076552-2401              50            16           75            0
# jcf7190000266316-165308           119            12           68           48
#
#                          DF_p8-major  DF_p8-minor  DF_p85-major  DF_p85-minor  \
# jcf7190000004922-46795            65           13            82            20
# jcf7190000168302-2649            322           26           372            29
# jcf7190000243153-2724             34           10            32            10
# jcf7190000076552-2401             53            7            34            20
# jcf7190000266316-165308           59           39            70            39
#
#                          DF_p86-major  DF_p86-minor  DF_p87-major  \
# jcf7190000004922-46795             87            23            76
# jcf7190000168302-2649             290            25           404
# jcf7190000243153-2724              16             7             0
# jcf7190000076552-2401              47             8            77
# jcf7190000266316-165308            75            44            97
#
#                          DF_p87-minor  DF_p88-major  DF_p88-minor  \
# jcf7190000004922-46795             25            71            32
# jcf7190000168302-2649              20           308            17
# jcf7190000243153-2724               0            30            13
# jcf7190000076552-2401               1            51             2
# jcf7190000266316-165308            32            41            42
#
#                          DF_p89-major  DF_p89-minor  DF_p9-major  DF_p9-minor  \
# jcf7190000004922-46795             54            14           73           31
# jcf7190000168302-2649             243            13          360           27
# jcf7190000243153-2724               0             0           33            8
# jcf7190000076552-2401              44             1           50           12
# jcf7190000266316-165308            30            63           55           48
#
#                          DF_p94-major  DF_p94-minor
# jcf7190000004922-46795            123            19
# jcf7190000168302-2649             301            15
# jcf7190000243153-2724              31             9
# jcf7190000076552-2401              39             7
# jcf7190000266316-165308            66            18

# %%
# assert that DP = RD + AD
dpcols = [col for col in reduced.columns if '.DP' in col]
for dpcol in dpcols:
    pop = dpcol.split(".")[0]
    adcol = f"{pop}.AD"
    rdcol = f"{pop}.RD"
    assert all(reduced[dpcol] == (reduced[adcol]+reduced[rdcol]))

# %%
baydir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass'

# %%
# make sure missing data makes sense
majorcols = [col for col in neutral_read_counts.columns if 'major' in col]
print(len(majorcols))
for locus in neutral_read_counts.index:
    misscount = 0
    for col in majorcols:
        pop = col.split("-")[0]
        if neutral_read_counts.loc[locus, col] == 0 and neutral_read_counts.loc[locus, "%s-minor" % pop] == 0:
            misscount += 1
    if misscount / len(majorcols) > 0.25:
        print('crap ', locus)
# Out:
# 42

# %%
# save
neutral_read_counts.to_csv(op.join(baydir, 'interior_neutral_gfile_HEADERIDX.txt'), sep='\t', index=True)
neutral_read_counts.to_csv(op.join(baydir, 'interior_neutral_gfile_noheaderidx.txt'), sep='\t', index=False, header=False)

# %% [markdown]
# #### <center> poolsizefile
#
# "For Pool–Seq experiment, the haploid size (twice the number of pooled in- dividuals for diploid species) of each population should be provided. ... The order of the populations in the pool size file must be the same as in the allele count (and the covariate) data file(s)."

# %%
DIR
# Out:
# '/data/projects/pool_seq/DF_datasets'

# %%
# the reason the ploidy.keys() are not in same order of table ...
# ... is because varscan puts Sample1.X then Sample10.X ... (JP_p31 is the 10th file into varscan)
ploidy = pklload(op.join(DIR, 'DF_pooled_GEA/DF_pooled/pkl_files/ploidy.pkl'))['DF_pooled']
count = 0
for k,v in ploidy.items():
    print(k,v)
    count += 1
    if count == 5:
        break
# Out:
# DF_p1 80
# DF_p10 80
# DF_p11 80
# DF_p12 80
# DF_p13 80

# %%
# get ploidy of pops in same order as in gfile
pops = [col.replace("-major","") for col in neutral_read_counts.columns if '-major' in col]
vals = OrderedDict()
for pop in pops:
    vals[pop] = OrderedDict()
    vals[pop][0] = ploidy[pop]
poolsizefile = pd.DataFrame(vals)
poolsizefile
# Out:
#    DF_p18  DF_p19  DF_p20  DF_p3  DF_p33  DF_p34  DF_p35  DF_p36  DF_p37  \
# 0      80      80      80     80      80      78      80      80      74
#
#    DF_p38  DF_p39  DF_p4  DF_p40  DF_p41  DF_p42  DF_p43  DF_p44  DF_p45  \
# 0      80      80     80      80      80      80      80      80      80
#
#    DF_p46  DF_p47  DF_p48  DF_p49  DF_p5  DF_p54  DF_p55  DF_p56  DF_p57  \
# 0      80      80      80      80     80      70      80      80      80
#
#    DF_p58  DF_p59  DF_p6  DF_p60  DF_p61  DF_p62  DF_p7  DF_p8  DF_p85  \
# 0      76      74     80      80      78      80     80     80      80
#
#    DF_p86  DF_p87  DF_p88  DF_p89  DF_p9  DF_p94
# 0      80      80      80      80     80      80

# %%
poolsizefile.shape
# Out:
# (1, 42)

# %%
neutral_read_counts.head()
# Out:
#                          DF_p18-major  DF_p18-minor  DF_p19-major  \
# jcf7190000004922-46795             72            22           105
# jcf7190000168302-2649             316            16           477
# jcf7190000243153-2724               0             0            67
# jcf7190000076552-2401               0             0            62
# jcf7190000266316-165308            82            10            93
#
#                          DF_p19-minor  DF_p20-major  DF_p20-minor  \
# jcf7190000004922-46795             25            64            15
# jcf7190000168302-2649              40           159            15
# jcf7190000243153-2724              11            19             9
# jcf7190000076552-2401              19            19             9
# jcf7190000266316-165308            14            40             6
#
#                          DF_p3-major  DF_p3-minor  DF_p33-major  DF_p33-minor  \
# jcf7190000004922-46795            93           23           103            13
# jcf7190000168302-2649            371           25           396            35
# jcf7190000243153-2724             39           14            33            11
# jcf7190000076552-2401              0            0            57            16
# jcf7190000266316-165308           92           10            75            40
#
#                          DF_p34-major  DF_p34-minor  DF_p35-major  \
# jcf7190000004922-46795             86            22           111
# jcf7190000168302-2649             368            24           400
# jcf7190000243153-2724              22             4            38
# jcf7190000076552-2401              60             8             0
# jcf7190000266316-165308            90            16            85
#
#                          DF_p35-minor  DF_p36-major  DF_p36-minor  \
# jcf7190000004922-46795             23            65            37
# jcf7190000168302-2649              41           264            20
# jcf7190000243153-2724              14            37            16
# jcf7190000076552-2401               0            63            11
# jcf7190000266316-165308            49            38            65
#
#                          DF_p37-major  DF_p37-minor  DF_p38-major  \
# jcf7190000004922-46795              0             0            51
# jcf7190000168302-2649             200            12           281
# jcf7190000243153-2724              18             8            37
# jcf7190000076552-2401               0             0            42
# jcf7190000266316-165308            35             5            76
#
#                          DF_p38-minor  DF_p39-major  DF_p39-minor  \
# jcf7190000004922-46795             13            49            17
# jcf7190000168302-2649              24           230            17
# jcf7190000243153-2724               7             0             0
# jcf7190000076552-2401               2            48             1
# jcf7190000266316-165308             9            59            35
#
#                          DF_p4-major  DF_p4-minor  DF_p40-major  DF_p40-minor  \
# jcf7190000004922-46795            97           20            36            10
# jcf7190000168302-2649            388           24           158            14
# jcf7190000243153-2724              0            0            27             8
# jcf7190000076552-2401             65           12            22             2
# jcf7190000266316-165308           56           62             8            27
#
#                          DF_p41-major  DF_p41-minor  DF_p42-major  \
# jcf7190000004922-46795             54            13            38
# jcf7190000168302-2649             211            19           177
# jcf7190000243153-2724              27            11            39
# jcf7190000076552-2401              27             2            33
# jcf7190000266316-165308            24            39            29
#
#                          DF_p42-minor  DF_p43-major  DF_p43-minor  \
# jcf7190000004922-46795              9            63            21
# jcf7190000168302-2649              17           292            20
# jcf7190000243153-2724               7             0             0
# jcf7190000076552-2401               3             0             0
# jcf7190000266316-165308            19            41            60
#
#                          DF_p44-major  DF_p44-minor  DF_p45-major  \
# jcf7190000004922-46795            118            29            67
# jcf7190000168302-2649             330            34           289
# jcf7190000243153-2724              25             4            41
# jcf7190000076552-2401              48            13            43
# jcf7190000266316-165308            99            37            56
#
#                          DF_p45-minor  DF_p46-major  DF_p46-minor  \
# jcf7190000004922-46795             13            71            22
# jcf7190000168302-2649              29           254            22
# jcf7190000243153-2724               7            31             8
# jcf7190000076552-2401               9            36             8
# jcf7190000266316-165308            53            64             8
#
#                          DF_p47-major  DF_p47-minor  DF_p48-major  \
# jcf7190000004922-46795            109            22            96
# jcf7190000168302-2649             384            23           418
# jcf7190000243153-2724               0             0            30
# jcf7190000076552-2401              41             3            56
# jcf7190000266316-165308            76            15            88
#
#                          DF_p48-minor  DF_p49-major  DF_p49-minor  \
# jcf7190000004922-46795             19           103            23
# jcf7190000168302-2649              35           339            31
# jcf7190000243153-2724               3            49             8
# jcf7190000076552-2401              10            65             7
# jcf7190000266316-165308            23            51            94
#
#                          DF_p5-major  DF_p5-minor  DF_p54-major  DF_p54-minor  \
# jcf7190000004922-46795            58           19           111            35
# jcf7190000168302-2649            303           29           436            31
# jcf7190000243153-2724             22           11            50            17
# jcf7190000076552-2401             48           17            75            26
# jcf7190000266316-165308           55            8           105            13
#
#                          DF_p55-major  DF_p55-minor  DF_p56-major  \
# jcf7190000004922-46795             91            25            93
# jcf7190000168302-2649             365            24           384
# jcf7190000243153-2724              32             7             0
# jcf7190000076552-2401              49            21            45
# jcf7190000266316-165308           107             1            76
#
#                          DF_p56-minor  DF_p57-major  DF_p57-minor  \
# jcf7190000004922-46795             37            96            32
# jcf7190000168302-2649              23           362            34
# jcf7190000243153-2724               0             0             0
# jcf7190000076552-2401              16            74             3
# jcf7190000266316-165308            21            86            32
#
#                          DF_p58-major  DF_p58-minor  DF_p59-major  \
# jcf7190000004922-46795            128            24            50
# jcf7190000168302-2649             387            33           260
# jcf7190000243153-2724              40             7            34
# jcf7190000076552-2401               0             0            35
# jcf7190000266316-165308           132             6            57
#
#                          DF_p59-minor  DF_p6-major  DF_p6-minor  DF_p60-major  \
# jcf7190000004922-46795             19           61           10           133
# jcf7190000168302-2649              23          383           22           400
# jcf7190000243153-2724               8           33            2            32
# jcf7190000076552-2401               3           84            0           102
# jcf7190000266316-165308            13            9          111           139
#
#                          DF_p60-minor  DF_p61-major  DF_p61-minor  \
# jcf7190000004922-46795             41           133            31
# jcf7190000168302-2649              32           446            34
# jcf7190000243153-2724               7            37            14
# jcf7190000076552-2401              13            48            12
# jcf7190000266316-165308             5            99            15
#
#                          DF_p62-major  DF_p62-minor  DF_p7-major  DF_p7-minor  \
# jcf7190000004922-46795            147            36          118           25
# jcf7190000168302-2649             394            31          407           28
# jcf7190000243153-2724              46             9           48           10
# jcf7190000076552-2401              50            16           75            0
# jcf7190000266316-165308           119            12           68           48
#
#                          DF_p8-major  DF_p8-minor  DF_p85-major  DF_p85-minor  \
# jcf7190000004922-46795            65           13            82            20
# jcf7190000168302-2649            322           26           372            29
# jcf7190000243153-2724             34           10            32            10
# jcf7190000076552-2401             53            7            34            20
# jcf7190000266316-165308           59           39            70            39
#
#                          DF_p86-major  DF_p86-minor  DF_p87-major  \
# jcf7190000004922-46795             87            23            76
# jcf7190000168302-2649             290            25           404
# jcf7190000243153-2724              16             7             0
# jcf7190000076552-2401              47             8            77
# jcf7190000266316-165308            75            44            97
#
#                          DF_p87-minor  DF_p88-major  DF_p88-minor  \
# jcf7190000004922-46795             25            71            32
# jcf7190000168302-2649              20           308            17
# jcf7190000243153-2724               0            30            13
# jcf7190000076552-2401               1            51             2
# jcf7190000266316-165308            32            41            42
#
#                          DF_p89-major  DF_p89-minor  DF_p9-major  DF_p9-minor  \
# jcf7190000004922-46795             54            14           73           31
# jcf7190000168302-2649             243            13          360           27
# jcf7190000243153-2724               0             0           33            8
# jcf7190000076552-2401              44             1           50           12
# jcf7190000266316-165308            30            63           55           48
#
#                          DF_p94-major  DF_p94-minor
# jcf7190000004922-46795            123            19
# jcf7190000168302-2649             301            15
# jcf7190000243153-2724              31             9
# jcf7190000076552-2401              39             7
# jcf7190000266316-165308            66            18

# %%
# save, no need to name as 'neutral'
poolsizefile.to_csv(op.join(baydir, 'interior_poolsizefile_HEADERIDX.txt'), sep='\t', index=False)
poolsizefile.to_csv(op.join(baydir, 'interior_poolsizefile_noheaderidx.txt'), sep='\t', index=False, header=False)

# %%
poolsizefile = pd.read_table(op.join(baydir, 'interior_poolsizefile_HEADERIDX.txt'))
poolsizefile
# Out:
#    DF_p18  DF_p19  DF_p20  DF_p3  DF_p33  DF_p34  DF_p35  DF_p36  DF_p37  \
# 0      80      80      80     80      80      78      80      80      74
#
#    DF_p38  DF_p39  DF_p4  DF_p40  DF_p41  DF_p42  DF_p43  DF_p44  DF_p45  \
# 0      80      80     80      80      80      80      80      80      80
#
#    DF_p46  DF_p47  DF_p48  DF_p49  DF_p5  DF_p54  DF_p55  DF_p56  DF_p57  \
# 0      80      80      80      80     80      70      80      80      80
#
#    DF_p58  DF_p59  DF_p6  DF_p60  DF_p61  DF_p62  DF_p7  DF_p8  DF_p85  \
# 0      76      74     80      80      78      80     80     80      80
#
#    DF_p86  DF_p87  DF_p88  DF_p89  DF_p9  DF_p94
# 0      80      80      80      80     80      80

# %% [markdown]
# #### <center> create random runs

# %% [markdown]
# #### estimate covariance matrix (run in bash)
# ```bash
# cd /lu213/brandon.lind/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/03_maf-p01_RD-recalculated/baypass
# mkdir neutral_runs
# cd neutral_runs
#
# export gfile="/lu213/brandon.lind/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/03_maf-p01_RD-recalculated/baypass/neutral_gfile_noheaderidx.txt"
#
# export poolsizefile="/lu213/brandon.lind/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/03_maf-p01_RD-recalculated/baypass/poolsizefile_noheaderidx.txt"
#
#
#
# # These commands took about 7 hours each to complete
#
#
# # chain 1
# /data/programs/baypass_2.2/sources/g_baypass -gfile $gfile -poolsizefile $poolsizefile \
# -nthreads 8 -seed $seed -print_omega_samples -outprefix chain_1 > chain_1_stdout.txt &
#
# # chain 2
# /data/programs/baypass_2.2/sources/g_baypass -gfile $gfile -poolsizefile $poolsizefile \
# -nthreads 8 -seed $seed -print_omega_samples -outprefix chain_2 > chain_2_stdout.txt &
#
# # chain 3
# /data/programs/baypass_2.2/sources/g_baypass -gfile $gfile -poolsizefile $poolsizefile \
# -nthreads 8 -seed $seed -print_omega_samples -outprefix chain_3 > chain_3_stdout.txt &
#
# # chain 4
# /data/programs/baypass_2.2/sources/g_baypass -gfile $gfile -poolsizefile $poolsizefile \
# -nthreads 8 -seed $seed -print_omega_samples -outprefix chain_4 > chain_4_stdout.txt &
#
# # chain 5
# /data/programs/baypass_2.2/sources/g_baypass -gfile $gfile -poolsizefile $poolsizefile \
# -nthreads 8 -seed $seed -print_omega_samples -outprefix chain_5 > chain_5_stdout.txt &
#
# ```

# %% [markdown]
# # look at covariance matrices output from chains

# %%
# get the matrix files output for each chain
ndir = op.join(baydir, 'neutral_runs_nval_30000_thr_6')
mfiles = fs(ndir, 'mat_omega.out')
mfiles
# Out:
# ['/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/neutral_runs_nval_30000_thr_6/FDI_chain_1_nval_30k_mat_omega.out',
#  '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/neutral_runs_nval_30000_thr_6/FDI_chain_2_nval_30k_mat_omega.out',
#  '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/neutral_runs_nval_30000_thr_6/FDI_chain_3_nval_30k_mat_omega.out',
#  '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/neutral_runs_nval_30000_thr_6/FDI_chain_4_nval_30k_mat_omega.out',
#  '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/neutral_runs_nval_30000_thr_6/FDI_chain_5_nval_30k_mat_omega.out']

# %%
# get a list of values by vectorizing the matrix for each chain
matrices = {}
for m in mfiles:
    chain = op.basename(m).split("_mat")[0]
    text = read(m)
    rows = []
    for line in text:
        rows.extend([float(val) for val in line.split()])
    matrices[chain] = rows
len(matrices[chain])
# Out:
# 1764

# %%
np.sqrt(1764)  # num pops
# Out:
# 42.0

# %%
from scipy.stats import pearsonr

# %%
# look at pairwise correlations among chains
for i,chaini in enumerate(matrices):
    for j,chainj in enumerate(matrices):
        if i < j:
            print(chaini,chainj,pearsonr(matrices[chaini], matrices[chainj]))
# Out:
# FDI_chain_1_nval_30k FDI_chain_2_nval_30k (0.9831515160358046, 0.0)
# FDI_chain_1_nval_30k FDI_chain_3_nval_30k (0.9847651429535893, 0.0)
# FDI_chain_1_nval_30k FDI_chain_4_nval_30k (0.9829301138300245, 0.0)
# FDI_chain_1_nval_30k FDI_chain_5_nval_30k (0.9840001979638344, 0.0)
# FDI_chain_2_nval_30k FDI_chain_3_nval_30k (0.989473935468978, 0.0)
# FDI_chain_2_nval_30k FDI_chain_4_nval_30k (0.9847718613032245, 0.0)
# FDI_chain_2_nval_30k FDI_chain_5_nval_30k (0.9852467777153512, 0.0)
# FDI_chain_3_nval_30k FDI_chain_4_nval_30k (0.9878181265390419, 0.0)
# FDI_chain_3_nval_30k FDI_chain_5_nval_30k (0.988079968580061, 0.0)
# FDI_chain_4_nval_30k FDI_chain_5_nval_30k (0.9884837627276469, 0.0)

# %%
# plot pairwise chains agains 1:1 line, print slope and intercept from data

import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms

def abline(slope, intercept):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '--')

for i,chaini in enumerate(matrices):
    for j,chainj in enumerate(matrices):
        if i < j:
            slope, intercept = np.polyfit(matrices[chaini], matrices[chainj], 1)
            print(chaini, chainj, slope, intercept)
            fig, ax = plt.subplots(figsize=(5,5))
            ax.scatter(matrices[chaini], matrices[chainj])
            ax.set_xlabel(chaini)
            ax.set_ylabel(chainj)
            line = mlines.Line2D([0, 1], [0, 1], color='red')
            transform = ax.transAxes
            line.set_transform(transform)
            ax.add_line(line)           
            
            plt.show()
# Out:
# FDI_chain_1_nval_30k FDI_chain_2_nval_30k 0.955795523619873 0.6108898963306589
# FDI_chain_1_nval_30k FDI_chain_3_nval_30k 0.9551994822502419 0.5627423071397474
# FDI_chain_1_nval_30k FDI_chain_4_nval_30k 0.9920319988126338 0.40125286266402993
# FDI_chain_1_nval_30k FDI_chain_5_nval_30k 0.9520616542367885 0.5740771399072278
# FDI_chain_2_nval_30k FDI_chain_3_nval_30k 0.9872365603658307 0.10765629271808676
# FDI_chain_2_nval_30k FDI_chain_4_nval_30k 1.0223371248464774 -0.03339172162065459
# FDI_chain_2_nval_30k FDI_chain_5_nval_30k 0.9805514178832198 0.16455399144215765
# FDI_chain_3_nval_30k FDI_chain_4_nval_30k 1.0278236840481878 -0.04633293344116622
# FDI_chain_3_nval_30k FDI_chain_5_nval_30k 0.9855997215206422 0.1548696374734687
# FDI_chain_4_nval_30k FDI_chain_5_nval_30k 0.9476247331918759 0.34675010369965487

# %%
# make a matrix with the average across matrices
mats = {}
for m in mfiles:
    chain = op.basename(m).split("_mat")[0]
    mats[chain] = pd.read_table(m, delim_whitespace=True, header=None)
mats[chain].head()
# Out:
#           0          1          2          3          4          5   \
# 0  13.279291  13.060093  13.143343  13.043018  13.017122  13.111273
# 1  13.060093  13.299572  13.136052  13.031004  12.994054  13.074715
# 2  13.143343  13.136052  13.361757  13.107475  13.061005  13.165207
# 3  13.043018  13.031004  13.107475  13.153741  13.064393  13.117538
# 4  13.017122  12.994054  13.061005  13.064393  13.127567  13.071232
#
#           6          7          8          9          10         11  \
# 0  12.861604  12.961693  12.917638  12.793161  12.865051  12.703220
# 1  12.842302  12.946974  12.917884  12.775421  12.837511  12.672159
# 2  12.874611  12.979617  12.959567  12.850745  12.878020  12.715515
# 3  12.829960  12.924424  12.995425  12.781044  12.832416  12.676582
# 4  12.812946  12.920522  13.000671  12.779984  12.834852  12.674184
#
#           12         13         14         15         16         17  \
# 0  12.680440  12.927986  12.977860  12.915173  12.608851  12.693324
# 1  12.666771  12.916432  12.959116  12.849706  12.564743  12.644364
# 2  12.681978  12.943909  13.013782  12.912420  12.620287  12.686311
# 3  12.610127  12.892787  12.948868  12.854919  12.554798  12.635229
# 4  12.625511  12.892440  12.928647  12.840780  12.537302  12.635706
#
#           18         19         20         21         22         23  \
# 0  13.290610  12.911924  12.770633  12.830730  13.151550  13.124476
# 1  13.248966  12.892146  12.743396  12.791237  13.134995  13.113766
# 2  13.341360  12.976780  12.802154  12.851929  13.195820  13.159977
# 3  13.278563  12.965805  12.746547  12.794187  13.111233  13.062917
# 4  13.220384  12.919826  12.739284  12.787017  13.089963  13.038672
#
#           24         25         26         27         28         29  \
# 0  12.953608  12.983050  12.958292  12.946687  13.145006  11.507977
# 1  13.030098  12.945694  12.913569  12.906227  13.097259  11.442337
# 2  13.017497  12.989370  12.995154  12.993054  13.151834  11.438116
# 3  12.904660  12.921525  12.921048  12.922933  13.057749  11.375433
# 4  12.877024  12.874122  12.882283  12.876003  13.019193  11.407451
#
#           30         31         32         33         34         35  \
# 0  12.773850  13.057655  12.924219  12.806262  13.001192  12.853325
# 1  12.754133  13.090662  12.963344  12.768481  12.972235  12.809291
# 2  12.791728  13.108340  12.977723  12.804708  13.016737  12.880439
# 3  12.710242  13.007192  12.884460  12.773558  12.960479  12.821684
# 4  12.678661  12.965085  12.843373  12.758185  12.958564  12.851179
#
#           36         37         38         39         40         41
# 0  12.715453  12.865134  12.956151  12.849727  12.904555  12.898732
# 1  12.690950  12.838802  12.915090  12.812369  12.851786  12.868261
# 2  12.718934  12.861726  12.977532  12.802078  12.899390  12.931751
# 3  12.680126  12.830692  12.925122  12.788667  12.846837  12.922396
# 4  12.667361  12.826309  12.913127  12.820710  12.845152  12.961742

# %%
chain
# Out:
# 'FDI_chain_1_nval_30k'

# %%
for chain,m in mats.items():
    print(chain)
    if 'chain_1' in chain:
        summatrix = np.array(m)
    else:
        summatrix = summatrix + np.array(m)
summatrix
# Out:
# FDI_chain_1_nval_30k
# FDI_chain_2_nval_30k
# FDI_chain_3_nval_30k
# FDI_chain_4_nval_30k
# FDI_chain_5_nval_30k
# array([[66.967365, 66.003742, 66.176415, ..., 64.548111, 65.184516,
#         64.811287],
#        [66.003742, 67.290629, 66.257968, ..., 64.488498, 65.015593,
#         64.788847],
#        [66.176415, 66.257968, 67.162754, ..., 64.20589 , 65.05858 ,
#         64.887378],
#        ...,
#        [64.548111, 64.488498, 64.20589 , ..., 64.287594, 63.981104,
#         63.601115],
#        [65.184516, 65.015593, 65.05858 , ..., 63.981104, 65.183492,
#         64.203134],
#        [64.811287, 64.788847, 64.887378, ..., 63.601115, 64.203134,
#         65.221959]])

# %%
avg = summatrix / len(mats)
avg.shape
# Out:
# (42, 42)

# %%
avgmat = pd.DataFrame(avg)
print(avgmat.shape)
avgmat.head()
# Out:
# (42, 42)
#            0          1          2          3          4          5  \
# 0  13.393473  13.200748  13.235283  13.122954  13.129178  13.237615
# 1  13.200748  13.458126  13.251594  13.133380  13.132861  13.220634
# 2  13.235283  13.251594  13.432551  13.164151  13.152350  13.268324
# 3  13.122954  13.133380  13.164151  13.197807  13.140202  13.203663
# 4  13.129178  13.132861  13.152350  13.140202  13.242714  13.189550
#
#            6          7          8          9         10         11  \
# 0  12.992768  13.039243  13.031562  12.910223  12.999579  12.830062
# 1  12.997290  13.044637  13.050948  12.914682  12.996908  12.817755
# 2  12.990778  13.037661  13.044215  12.944663  12.992404  12.821781
# 3  12.926750  12.968885  13.070161  12.864954  12.928184  12.762670
# 4  12.946234  12.996767  13.107140  12.891452  12.970785  12.794471
#
#           12         13         14         15         16         17  \
# 0  12.754133  13.034261  13.106469  13.008893  12.712765  12.877985
# 1  12.759773  13.047253  13.103623  12.966774  12.690297  12.848576
# 2  12.745039  13.028004  13.114141  12.988531  12.704725  12.850364
# 3  12.654305  12.962135  13.033145  12.912479  12.624476  12.780517
# 4  12.704702  13.002101  13.051777  12.937791  12.642963  12.818162
#
#           18         19         20         21         22         23  \
# 0  13.374544  13.060717  12.886343  12.913522  13.269598  13.218687
# 1  13.356796  13.065621  12.879619  12.895731  13.269430  13.227787
# 2  13.405156  13.101904  12.896274  12.913942  13.286298  13.231670
# 3  13.327273  13.078293  12.823011  12.839910  13.184431  13.116342
# 4  13.305873  13.066187  12.851839  12.872123  13.205160  13.128726
#
#           24         25         26         27         28         29  \
# 0  13.058227  13.102237  13.032017  13.053428  13.282463  11.587839
# 1  13.154197  13.090684  12.999749  13.034167  13.255371  11.535749
# 2  13.096463  13.088414  13.036772  13.075180  13.262421  11.491602
# 3  12.971711  13.007103  12.950848  12.994985  13.154513  11.417246
# 4  12.976561  12.996604  12.946343  12.983034  13.159207  11.483251
#
#           30         31         32         33         34         35  \
# 0  12.884380  13.165644  13.046041  12.909866  13.047629  12.962405
# 1  12.882821  13.215169  13.107840  12.896702  13.042007  12.936284
# 2  12.876879  13.191924  13.079083  12.888957  13.043468  12.965424
# 3  12.782379  13.079565  12.969692  12.839626  12.971089  12.893374
# 4  12.788994  13.071242  12.965991  12.861926  13.006890  12.954631
#
#           36         37         38         39         40         41
# 0  12.835967  12.959007  13.040347  12.909622  13.036903  12.962257
# 1  12.836426  12.951931  13.022003  12.897700  13.003119  12.957769
# 2  12.821275  12.939874  13.039103  12.841178  13.011716  12.977476
# 3  12.763923  12.888716  12.972065  12.814561  12.942251  12.950306
# 4  12.788711  12.924300  12.994861  12.884096  12.980903  13.029395

# %%
# make sure avgmat is highly correlated with other chains
avgmatlst = []
for row in avgmat.index:
    for col in avgmat.columns:
        avgmatlst.append(avgmat.loc[row, col])
print(len(avgmatlst), len(matrices[chain]))

for chain,lst in matrices.items():
    print(chain, pearsonr(matrices[chain], avgmatlst))
# Out:
# 1764 1764
# FDI_chain_1_nval_30k (0.9926515853247961, 0.0)
# FDI_chain_2_nval_30k (0.9941162123950715, 0.0)
# FDI_chain_3_nval_30k (0.995630452336252, 0.0)
# FDI_chain_4_nval_30k (0.9944983716587971, 0.0)
# FDI_chain_5_nval_30k (0.9947652550335342, 0.0)

# %%
baydir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass'

# %%
# save average matrix
omegafile = op.join(baydir, 'interior_neutral_average_omegafile_noheaderidx.txt')
avgmat.to_csv(omegafile, sep='\t', index=False, header=False)

# %% [markdown]
# #### make sure pops are in same order as gfile

# %%
poolsizefile = pd.read_table(op.join(baydir, 'interior_poolsizefile_HEADERIDX.txt'))
poolsizefile
# Out:
#    DF_p18  DF_p19  DF_p20  DF_p3  DF_p33  DF_p34  DF_p35  DF_p36  DF_p37  \
# 0      80      80      80     80      80      78      80      80      74
#
#    DF_p38  DF_p39  DF_p4  DF_p40  DF_p41  DF_p42  DF_p43  DF_p44  DF_p45  \
# 0      80      80     80      80      80      80      80      80      80
#
#    DF_p46  DF_p47  DF_p48  DF_p49  DF_p5  DF_p54  DF_p55  DF_p56  DF_p57  \
# 0      80      80      80      80     80      70      80      80      80
#
#    DF_p58  DF_p59  DF_p6  DF_p60  DF_p61  DF_p62  DF_p7  DF_p8  DF_p85  \
# 0      76      74     80      80      78      80     80     80      80
#
#    DF_p86  DF_p87  DF_p88  DF_p89  DF_p9  DF_p94
# 0      80      80      80      80     80      80

# %%
gfile = pd.read_table(op.join(baydir, 'interior_neutral_gfile_HEADERIDX.txt'), index_col=0)
gfilecols = [list(gfile.columns)[i].split("-")[0] for i in range(0,len(gfile.columns),2)]
pd.DataFrame(columns=gfilecols)  # just so it prints pretty
# Out:
# Empty DataFrame
# Columns: [DF_p18, DF_p19, DF_p20, DF_p3, DF_p33, DF_p34, DF_p35, DF_p36, DF_p37, DF_p38, DF_p39, DF_p4, DF_p40, DF_p41, DF_p42, DF_p43, DF_p44, DF_p45, DF_p46, DF_p47, DF_p48, DF_p49, DF_p5, DF_p54, DF_p55, DF_p56, DF_p57, DF_p58, DF_p59, DF_p6, DF_p60, DF_p61, DF_p62, DF_p7, DF_p8, DF_p85, DF_p86, DF_p87, DF_p88, DF_p89, DF_p9, DF_p94]
# Index: []

# %%
list(poolsizefile.columns) == gfilecols
# Out:
# True

# %%
# now apply to avgmat
avgmat.columns = gfilecols
avgmat.index = gfilecols
avgmat.head()
# Out:
#            DF_p18     DF_p19     DF_p20      DF_p3     DF_p33     DF_p34  \
# DF_p18  13.393473  13.200748  13.235283  13.122954  13.129178  13.237615
# DF_p19  13.200748  13.458126  13.251594  13.133380  13.132861  13.220634
# DF_p20  13.235283  13.251594  13.432551  13.164151  13.152350  13.268324
# DF_p3   13.122954  13.133380  13.164151  13.197807  13.140202  13.203663
# DF_p33  13.129178  13.132861  13.152350  13.140202  13.242714  13.189550
#
#            DF_p35     DF_p36     DF_p37     DF_p38     DF_p39      DF_p4  \
# DF_p18  12.992768  13.039243  13.031562  12.910223  12.999579  12.830062
# DF_p19  12.997290  13.044637  13.050948  12.914682  12.996908  12.817755
# DF_p20  12.990778  13.037661  13.044215  12.944663  12.992404  12.821781
# DF_p3   12.926750  12.968885  13.070161  12.864954  12.928184  12.762670
# DF_p33  12.946234  12.996767  13.107140  12.891452  12.970785  12.794471
#
#            DF_p40     DF_p41     DF_p42     DF_p43     DF_p44     DF_p45  \
# DF_p18  12.754133  13.034261  13.106469  13.008893  12.712765  12.877985
# DF_p19  12.759773  13.047253  13.103623  12.966774  12.690297  12.848576
# DF_p20  12.745039  13.028004  13.114141  12.988531  12.704725  12.850364
# DF_p3   12.654305  12.962135  13.033145  12.912479  12.624476  12.780517
# DF_p33  12.704702  13.002101  13.051777  12.937791  12.642963  12.818162
#
#            DF_p46     DF_p47     DF_p48     DF_p49      DF_p5     DF_p54  \
# DF_p18  13.374544  13.060717  12.886343  12.913522  13.269598  13.218687
# DF_p19  13.356796  13.065621  12.879619  12.895731  13.269430  13.227787
# DF_p20  13.405156  13.101904  12.896274  12.913942  13.286298  13.231670
# DF_p3   13.327273  13.078293  12.823011  12.839910  13.184431  13.116342
# DF_p33  13.305873  13.066187  12.851839  12.872123  13.205160  13.128726
#
#            DF_p55     DF_p56     DF_p57     DF_p58     DF_p59      DF_p6  \
# DF_p18  13.058227  13.102237  13.032017  13.053428  13.282463  11.587839
# DF_p19  13.154197  13.090684  12.999749  13.034167  13.255371  11.535749
# DF_p20  13.096463  13.088414  13.036772  13.075180  13.262421  11.491602
# DF_p3   12.971711  13.007103  12.950848  12.994985  13.154513  11.417246
# DF_p33  12.976561  12.996604  12.946343  12.983034  13.159207  11.483251
#
#            DF_p60     DF_p61     DF_p62      DF_p7      DF_p8     DF_p85  \
# DF_p18  12.884380  13.165644  13.046041  12.909866  13.047629  12.962405
# DF_p19  12.882821  13.215169  13.107840  12.896702  13.042007  12.936284
# DF_p20  12.876879  13.191924  13.079083  12.888957  13.043468  12.965424
# DF_p3   12.782379  13.079565  12.969692  12.839626  12.971089  12.893374
# DF_p33  12.788994  13.071242  12.965991  12.861926  13.006890  12.954631
#
#            DF_p86     DF_p87     DF_p88     DF_p89      DF_p9     DF_p94
# DF_p18  12.835967  12.959007  13.040347  12.909622  13.036903  12.962257
# DF_p19  12.836426  12.951931  13.022003  12.897700  13.003119  12.957769
# DF_p20  12.821275  12.939874  13.039103  12.841178  13.011716  12.977476
# DF_p3   12.763923  12.888716  12.972065  12.814561  12.942251  12.950306
# DF_p33  12.788711  12.924300  12.994861  12.884096  12.980903  13.029395

# %% [markdown]
# # make efile

# %%
baydir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass'

# %%
poolsizefile
# Out:
#    DF_p18  DF_p19  DF_p20  DF_p3  DF_p33  DF_p34  DF_p35  DF_p36  DF_p37  \
# 0      80      80      80     80      80      78      80      80      74
#
#    DF_p38  DF_p39  DF_p4  DF_p40  DF_p41  DF_p42  DF_p43  DF_p44  DF_p45  \
# 0      80      80     80      80      80      80      80      80      80
#
#    DF_p46  DF_p47  DF_p48  DF_p49  DF_p5  DF_p54  DF_p55  DF_p56  DF_p57  \
# 0      80      80      80      80     80      70      80      80      80
#
#    DF_p58  DF_p59  DF_p6  DF_p60  DF_p61  DF_p62  DF_p7  DF_p8  DF_p85  \
# 0      76      74     80      80      78      80     80     80      80
#
#    DF_p86  DF_p87  DF_p88  DF_p89  DF_p9  DF_p94
# 0      80      80      80      80     80      80

# %%
envdata = pd.read_table('/data/projects/pool_seq/environemental_data/df_raw_env-19variables.txt')
envdata.index = envdata['our_id'].tolist()
envdata = envdata[envdata.index.isin(poolsizefile.columns)]
envdata
# Out:
#         prov  our_id Variety    LONG    LAT  Elevation  MAT  MWMT  MCMT    TD  \
# DF_p3      3   DF_p3     FDI -115.62  50.54       1525  1.6  13.4 -10.7  24.1
# DF_p4      4   DF_p4     FDI -122.33  52.04        900  3.9  15.3  -9.2  24.5
# DF_p5      5   DF_p5     FDI -119.05  49.02        853  6.0  17.7  -6.2  23.9
# DF_p6      6   DF_p6     FDI -125.75  52.28        460  5.1  15.8  -7.3  23.2
# DF_p7      7   DF_p7     FDI -122.13  53.98        684  3.4  15.0 -10.3  25.3
# DF_p8      8   DF_p8     FDI -124.38  54.35        850  2.1  13.7 -11.3  25.0
# DF_p9      9   DF_p9     FDI -119.72  53.12        780  2.9  14.4  -9.6  24.1
# DF_p18    18  DF_p18     FDI -116.83  48.33        823  6.6  18.0  -4.6  22.6
# DF_p19    19  DF_p19     FDI -116.00  45.83        686  8.3  19.6  -2.2  21.8
# DF_p20    20  DF_p20     FDI -114.50  48.08       1341  5.2  17.1  -5.8  22.9
# DF_p33    33  DF_p33     FDI -116.25  51.03       1524  0.9  12.7 -11.4  24.1
# DF_p34    34  DF_p34     FDI -114.78  49.80       1615  1.3  13.1 -10.0  23.1
# DF_p35    35  DF_p35     FDI -122.00  52.00        732  4.6  16.2  -8.7  24.9
# DF_p36    36  DF_p36     FDI -123.75  52.00       1047  2.5  13.6 -10.0  23.6
# DF_p37    37  DF_p37     FDI -115.55  51.18       1370  1.4  13.3 -11.6  24.9
# DF_p38    38  DF_p38     FDI -118.03  52.92       1025  2.1  14.1 -11.3  25.4
# DF_p39    39  DF_p39     FDI -122.10  52.68        610  4.8  16.4  -8.7  25.1
# DF_p40    40  DF_p40     FDI -124.71  51.72       1250  1.8  11.7  -8.9  20.6
# DF_p41    41  DF_p41     FDI -120.40  53.41        760  3.6  14.6  -9.0  23.6
# DF_p42    42  DF_p42     FDI -123.60  53.55        975  2.1  13.9 -11.3  25.1
# DF_p43    43  DF_p43     FDI -120.83  51.52        750  4.3  14.9  -8.4  23.3
# DF_p44    44  DF_p44     FDI -120.87  50.71        800  5.3  16.9  -7.1  24.0
# DF_p45    45  DF_p45     FDI -119.78  51.77        850  4.5  16.2  -7.6  23.9
# DF_p46    46  DF_p46     FDI -117.13  49.21       1500  2.9  14.2  -7.6  21.8
# DF_p47    47  DF_p47     FDI -117.47  51.52       1100  2.8  14.7  -9.7  24.4
# DF_p48    48  DF_p48     FDI -122.84  54.83        850  1.7  14.0 -12.0  26.0
# DF_p49    49  DF_p49     FDI -119.34  50.58        525  6.8  18.3  -5.2  23.4
# DF_p54    54  DF_p54     FDI -118.33  44.75       1606  5.2  16.4  -4.8  21.1
# DF_p55    55  DF_p55     FDI -115.92  45.92        716  8.6  20.0  -2.3  22.3
# DF_p56    56  DF_p56     FDI -117.25  48.35        853  6.6  18.0  -4.9  22.9
# DF_p57    57  DF_p57     FDI -115.83  48.50       1158  5.4  16.5  -5.4  21.9
# DF_p58    58  DF_p58     FDI -114.58  46.58       1341  4.2  15.9  -6.4  22.3
# DF_p59    59  DF_p59     FDI -116.58  47.92       1250  5.3  16.5  -4.8  21.4
# DF_p60    60  DF_p60     FDI -116.17  46.83       1036  6.2  17.2  -4.1  21.4
# DF_p61    61  DF_p61     FDI -116.17  45.67       1737  5.5  17.2  -4.6  21.8
# DF_p62    62  DF_p62     FDI -113.83  47.25       1158  5.1  16.7  -6.3  23.0
# DF_p85    85  DF_p85     FDI -117.71  50.13       1086  4.8  16.1  -6.2  22.4
# DF_p86    86  DF_p86     FDI -122.25  52.85        830  3.7  15.2  -9.0  24.2
# DF_p87    87  DF_p87     FDI -122.78  53.58        772  3.2  14.9 -10.1  25.0
# DF_p88    88  DF_p88     FDI -120.92  52.35        925  3.5  14.4  -8.4  22.8
# DF_p89    89  DF_p89     FDI -118.63  50.74        641  6.1  17.6  -5.9  23.4
# DF_p94    94  DF_p94     FDI -117.20  51.40       1013  3.0  14.9  -9.7  24.6
#
#          MAP  MSP   AHM    SHM  DD_0   DD5  NFFD  bFFP  eFFP  FFP  PAS   EMT  \
# DF_p3    630  321  18.5   41.8  1242   929   130   171   244   73  261 -43.3
# DF_p4    423  196  32.9   78.2   919  1270   158   154   255  101  149 -40.2
# DF_p5    367  171  43.8  103.6   637  1650   182   142   265  123  100 -34.8
# DF_p6    827  180  18.2   87.8   741  1440   172   149   257  108  351 -38.4
# DF_p7    880  341  15.2   43.9  1031  1239   162   150   256  106  372 -40.5
# DF_p8    572  235  21.1   58.4  1210   991   143   164   250   86  262 -42.3
# DF_p9    542  229  23.8   63.1  1052  1136   154   156   255   99  225 -40.6
# DF_p18   831  232  20.0   77.8   483  1670   190   144   266  122  239 -31.2
# DF_p19   666  290  27.5   67.8   311  1975   211   135   273  138   70 -28.7
# DF_p20   471  215  32.3   79.5   648  1475   170   153   258  105  133 -33.7
# DF_p33   901  324  12.1   39.1  1379   826   125   170   240   70  511 -44.3
# DF_p34   704  261  16.0   50.2  1252   847   138   164   249   85  390 -41.5
# DF_p35   435  215  33.6   75.3   843  1416   168   149   258  109  134 -38.8
# DF_p36   369  181  33.9   75.0  1086  1008   127   172   241   69  138 -44.4
# DF_p37   341  195  33.3   68.3  1323   912   126   171   240   69  125 -44.7
# DF_p38   355  193  34.2   73.1  1235  1061   142   161   248   88  122 -44.0
# DF_p39   496  245  29.8   66.9   828  1450   172   144   261  116  152 -38.7
# DF_p40   597  236  19.8   49.7  1055   770   120   178   241   63  281 -42.5
# DF_p41   657  301  20.7   48.7   926  1215   162   153   257  104  233 -39.2
# DF_p42   560  235  21.6   59.1  1204  1002   140   165   249   83  250 -43.0
# DF_p43   326  152  43.8   98.5   836  1279   153   158   247   89  109 -39.1
# DF_p44   323  155  47.5  108.8   727  1522   179   142   265  123   94 -36.3
# DF_p45   966  349  15.0   46.6   816  1409   175   144   263  119  370 -37.0
# DF_p46  1564  450   8.3   31.7   931  1029   164   149   266  117  824 -35.9
# DF_p47   841  210  15.2   69.9  1067  1119   154   155   255  100  486 -40.0
# DF_p48   903  299  12.9   46.7  1322  1011   149   159   254   94  491 -42.3
# DF_p49   503  195  33.4   93.5   535  1771   202   133   270  137  135 -32.0
# DF_p54   621  153  24.5  106.7   568  1337   163   165   265   99  245 -33.5
# DF_p55   682  263  27.2   75.9   311  2060   215   130   274  145   84 -28.9
# DF_p56   814  237  20.3   75.9   508  1673   186   145   265  120  243 -32.3
# DF_p57   949  280  16.2   59.0   599  1462   176   153   264  112  334 -33.3
# DF_p58  1097  286  12.9   55.6   755  1245   138   178   246   67  527 -35.8
# DF_p59  1263  374  12.1   44.1   565  1365   185   147   269  122  436 -31.7
# DF_p60  1004  241  16.2   71.4   480  1540   176   150   256  106  323 -31.9
# DF_p61   870  316  17.8   54.3   572  1438   173   156   268  112  273 -33.0
# DF_p62   923  265  16.3   63.1   675  1434   153   161   251   90  386 -36.8
# DF_p85  1020  326  14.5   49.6   710  1386   182   145   269  124  401 -33.2
# DF_p86   565  273  24.3   55.6   919  1227   163   151   258  107  196 -39.3
# DF_p87   603  268  21.9   55.7  1029  1169   159   153   255  102  233 -40.7
# DF_p88   728  349  18.6   41.4   890  1126   152   160   252   93  254 -39.5
# DF_p89   751  271  21.4   64.7   611  1704   201   132   274  142  238 -32.1
# DF_p94   643  215  20.2   69.3  1054  1159   155   154   254  100  328 -40.3
#
#          EXT  Eref  CMD
# DF_p3   32.6   548  151
# DF_p4   34.9   598  350
# DF_p5   37.7   732  497
# DF_p6   35.0   667  392
# DF_p7   33.6   552  174
# DF_p8   32.4   521  240
# DF_p9   32.8   539  259
# DF_p18  37.8   768  391
# DF_p19  40.0   869  368
# DF_p20  36.4   680  397
# DF_p33  32.1   518  131
# DF_p34  30.8   489  158
# DF_p35  35.3   656  367
# DF_p36  33.9   592  364
# DF_p37  32.6   547  306
# DF_p38  32.7   541  301
# DF_p39  35.3   646  327
# DF_p40  31.6   528  241
# DF_p41  33.0   553  203
# DF_p42  32.4   533  249
# DF_p43  34.7   672  466
# DF_p44  35.6   665  455
# DF_p45  34.4   577  159
# DF_p46  32.1   493   51
# DF_p47  33.3   546  272
# DF_p48  32.1   490  147
# DF_p49  37.2   718  422
# DF_p54  36.1   709  463
# DF_p55  40.8   875  406
# DF_p56  38.4   773  391
# DF_p57  36.4   697  287
# DF_p58  36.4   693  307
# DF_p59  35.0   645  164
# DF_p60  38.1   787  381
# DF_p61  36.4   690  254
# DF_p62  36.8   718  358
# DF_p85  34.0   575  169
# DF_p86  33.3   557  230
# DF_p87  33.2   546  227
# DF_p88  33.7   569  155
# DF_p89  37.2   662  284
# DF_p94  33.6   561  289

# %%
# center/standardize
for env in list(envdata.columns)[6:]:
    mn = np.mean(envdata[env])
    std = np.std(envdata[env])
    for pop in envdata.index:
        envdata.loc[pop, env] = (envdata.loc[pop, env] - mn) / std
    print(env, np.mean(envdata[env]), np.std(envdata[env]))
# Out:
# MAT 2.8019914431015855e-16 0.9999999999999999
# MWMT 6.88602614082984e-16 0.9999999999999999
# MCMT -4.414458216961932e-16 1.0
# TD 1.9217431878630687e-15 1.0
# MAP -1.5463820700136108e-16 0.9999999999999999
# MSP 2.379049338482478e-16 1.0
# AHM -3.938648349265436e-16 1.0
# SHM 6.079792753899667e-17 0.9999999999999999
# DD_0 -8.194503276995204e-17 1.0
# DD5 -1.1895246692412391e-17 1.0
# NFFD -2.352615456943784e-16 1.0
# bFFP 1.0428579296413905e-15 0.9999999999999999
# eFFP -8.630662322383657e-16 1.0
# FFP 1.367953369627425e-16 1.0
# PAS -1.7182023000151233e-17 1.0000000000000002
# EMT -1.6653345369377348e-16 1.0
# EXT 8.353106566227368e-16 1.0
# Eref 1.4538634846281812e-16 1.0
# CMD 9.111428542868659e-17 1.0

# %%
# convert envdata to efile, making sure to order pops in same order as other files
efile = envdata.loc[poolsizefile.columns.tolist(), list(envdata.columns)[6:]]
efile.head()
# Out:
#              MAT      MWMT      MCMT        TD       MAP       MSP       AHM  \
# DF_p18  1.301783  1.296208  1.242564 -0.650024  0.477275 -0.359626 -0.333556
# DF_p19  2.210358  2.169881  2.167604 -1.258404 -0.144555  0.535214  0.482206
# DF_p20  0.553544  0.804767  0.780044 -0.421882 -0.879446 -0.621907  1.004294
# DF_p3  -1.370499 -1.215602 -1.108580  0.490687 -0.280228  1.013491 -0.496709
# DF_p33 -1.744618 -1.597834 -1.378383  0.490687  0.741082  1.059776 -1.192826
#
#              SHM      DD_0       DD5      NFFD      bFFP      eFFP       FFP  \
# DF_p18  0.665959 -1.312971  1.230208  1.181696 -0.851012  0.927683  0.909336
# DF_p19  0.130438 -1.921017  2.253982  2.099984 -1.622432  1.666813  1.685795
# DF_p20  0.756997 -0.729672  0.575663  0.307137 -0.079591  0.082964  0.084348
# DF_p3  -1.261917  1.370207 -1.257061 -1.441982  1.463250 -1.395296 -1.468571
# DF_p33 -1.406507  1.854522 -1.602795 -1.660622  1.377537 -1.817656 -1.614158
#
#              PAS       EMT       EXT      Eref       CMD
# DF_p18 -0.232110  1.425686  1.290227  1.428825  0.936304
# DF_p19 -1.352869  1.981561  2.237144  2.445613  0.721924
# DF_p20 -0.935071  0.869811  0.687643  0.542910  0.992230
# DF_p3  -0.086212 -1.264747 -0.947942 -0.785961 -1.300706
# DF_p33  1.571716 -1.487097 -1.163151 -1.087978 -1.487124

# %%
for env in efile:
    print(env, np.mean(efile[env]), np.std(efile[env]))
# Out:
# MAT 2.6962559169468085e-16 0.9999999999999999
# MWMT 6.780290614675063e-16 0.9999999999999998
# MCMT -4.440892098500626e-16 1.0
# TD 1.9217431878630687e-15 1.0
# MAP -1.149873846933198e-16 0.9999999999999999
# MSP 2.32618157540509e-16 1.0
# AHM -3.674309533878494e-16 1.0
# SHM 7.79799505391479e-17 1.0
# DD_0 -8.194503276995204e-17 1.0
# DD5 -1.1895246692412391e-17 1.0
# NFFD -2.5640865092533375e-16 1.0
# bFFP 1.0573965644876723e-15 0.9999999999999999
# eFFP -8.498492914690187e-16 1.0
# FFP 1.2886517250113425e-16 1.0
# PAS -5.28677630773884e-18 1.0
# EMT -1.691768418476429e-16 1.0
# EXT 8.458842092382145e-16 1.0
# Eref 1.6124667738603463e-16 0.9999999999999999
# CMD 1.3093031949634474e-16 1.0

# %%
######################### VERY IMPORTANT!
# transpose df so pops are columns and env are rows
#########################
efile = efile.T
efile.head()
# Out:
#         DF_p18    DF_p19    DF_p20     DF_p3    DF_p33    DF_p34    DF_p35  \
# MAT   1.301783  2.210358  0.553544 -1.370499 -1.744618 -1.530835  0.232870
# MWMT  1.296208  2.169881  0.804767 -1.215602 -1.597834 -1.379415  0.313326
# MCMT  1.242564  2.167604  0.780044 -1.108580 -1.378383 -0.838776 -0.337713
# TD   -0.650024 -1.258404 -0.421882  0.490687  0.490687 -0.269787  1.099066
# MAP   0.477275 -0.144555 -0.879446 -0.280228  0.741082 -0.001346 -1.015118
#
#         DF_p36    DF_p37    DF_p38    DF_p39     DF_p4    DF_p40    DF_p41  \
# MAT  -0.889488 -1.477390 -1.103270  0.339761 -0.141249 -1.263607 -0.301586
# MWMT -1.106393 -1.270206 -0.833370  0.422535 -0.178115 -2.143879 -0.560347
# MCMT -0.838776 -1.455470 -1.339840 -0.337713 -0.530430 -0.414800 -0.453343
# TD    0.110450  1.099066  1.479303  1.251161  0.794876 -2.170972  0.110450
# MAP  -1.263850 -1.369373 -1.316612 -0.785229 -1.060342 -0.404594 -0.178473
#
#         DF_p42    DF_p43    DF_p44    DF_p45    DF_p46    DF_p47    DF_p48  \
# MAT  -1.103270  0.072533  0.606990  0.179425 -0.675705 -0.729151 -1.317053
# MWMT -0.942579 -0.396533  0.695558  0.313326 -0.778765 -0.505742 -0.887974
# MCMT -1.339840 -0.222083  0.278980  0.086264  0.086264 -0.723146 -1.609643
# TD    1.251161 -0.117692  0.414639  0.338592 -1.258404  0.718829  1.935588
# MAP  -0.544034 -1.425903 -1.437209  0.986046  3.239710  0.514962  0.748619
#
#         DF_p49     DF_p5    DF_p54    DF_p55    DF_p56    DF_p57    DF_p58  \
# MAT   1.408674  0.981109  0.553544  2.370695  1.301783  0.660435  0.019088
# MWMT  1.460022  1.132395  0.422535  2.388300  1.296208  0.477140  0.149513
# MCMT  1.011304  0.625870  1.165477  2.129060  1.126934  0.934217  0.548784
# TD   -0.041645  0.338592 -1.790735 -0.878167 -0.421882 -1.182356 -0.878167
# MAP  -0.758849 -1.271388 -0.314146 -0.084257  0.413208  0.921978  1.479741
#
#         DF_p59     DF_p6    DF_p60    DF_p61    DF_p62     DF_p7     DF_p8  \
# MAT   0.606990  0.500098  1.088000  0.713881  0.500098 -0.408477 -1.103270
# MWMT  0.477140  0.094908  0.859372  0.859372  0.586349 -0.341929 -1.051788
# MCMT  1.165477  0.201894  1.435280  1.242564  0.587327 -0.954406 -1.339840
# TD   -1.562593 -0.193740 -1.562593 -1.258404 -0.345835  1.403256  1.175114
# MAP   2.105341  0.462200  1.129255  0.624253  0.823993  0.661940 -0.498810
#
#         DF_p85    DF_p86    DF_p87    DF_p88    DF_p89     DF_p9    DF_p94
# MAT   0.339761 -0.248140 -0.515369 -0.355032  1.034555 -0.675705 -0.622260
# MWMT  0.258722 -0.232719 -0.396533 -0.669556  1.077790 -0.669556 -0.396533
# MCMT  0.625870 -0.453343 -0.877320 -0.222083  0.741500 -0.684603 -0.723146
# TD   -0.802119  0.566734  1.175114 -0.497929 -0.041645  0.490687  0.870924
# MAP   1.189554 -0.525191 -0.381982  0.089102  0.175782 -0.611871 -0.231235

# %%
# save
efile.to_csv(op.join(baydir, 'interior_efile_std_HEADERIDX.txt'), sep='\t', index=True, header=True)
efile.to_csv(op.join(baydir, 'interior_efile_std_noheaderidx.txt'), sep='\t', index=False, header=False)

# %%
# save a separate efile for each env so I can run the MCMC algorithm for GEA
envdir = makedir(op.join(baydir, 'individual_efiles'))
for env in efile.index:
    df = pd.DataFrame(efile.loc[env, :]).T
    df.to_csv(op.join(envdir, 'interior_%s_HEADERIDX.txt' % env), sep='\t', index=True, header=True)
    df.to_csv(op.join(envdir, 'interior_%s_noheaderidx.txt' % env), sep='\t', index=False, header=False)
df
# Out:
#        DF_p18    DF_p19   DF_p20     DF_p3    DF_p33   DF_p34    DF_p35  \
# CMD  0.936304  0.721924  0.99223 -1.300706 -1.487124 -1.23546  0.712603
#
#        DF_p36   DF_p37    DF_p38    DF_p39     DF_p4    DF_p40    DF_p41  \
# CMD  0.684641  0.14403  0.097425  0.339768  0.554148 -0.461827 -0.816021
#
#       DF_p42   DF_p43   DF_p44    DF_p45    DF_p46   DF_p47   DF_p48  \
# CMD -0.38726  1.63537  1.53284 -1.226139 -2.232794 -0.17288 -1.33799
#
#        DF_p49     DF_p5    DF_p54    DF_p55    DF_p56    DF_p57    DF_p58  \
# CMD  1.225251  1.924317  1.607407  1.076117  0.936304 -0.033067  0.153351
#
#        DF_p59     DF_p6    DF_p60    DF_p61    DF_p62     DF_p7     DF_p8  \
# CMD -1.179535  0.945625  0.843095 -0.340656  0.628715 -1.086326 -0.471148
#
#       DF_p85    DF_p86   DF_p87    DF_p88   DF_p89     DF_p9    DF_p94
# CMD -1.13293 -0.564357 -0.59232 -1.263423 -0.06103 -0.294051 -0.014425

# %%
op.join(baydir, 'interior_efile_std_noheaderidx.txt')
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/interior_efile_std_noheaderidx.txt'

# %%
# !echo $HOSTNAME
# Out:
# itbioyeaman03.ucalgary.ca

# %% [markdown]
# # create gfiles for GEA from "SNP" files (ADP < 1000)

# %%
linenums
# Out:
# {'/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/DF_pooled-varscan_all_bedfiles_SNP_FDI_maf_RD-recalculated.txt': 2609583}

# %%
# read in snps in parallel
f = keys(linenums)[0]
nrows = 10000
jobs = []
for skipto in range(0, linenums[f], nrows):
    jobs.append(lview.apply_async(get_skipto_df, *(f, skipto, nrows)))
watch_async(jobs)
# Out:
# 53
# 53

# %%
# get job returns
snps = pd.concat([j.r for j in jobs])
snps.index = snps['locus'].tolist()
snps.head()
# Out:
#                                    CHROM    POS REF ALT        AF  QUAL TYPE  \
# jcf7190000000000-77602  jcf7190000000000  77602   G   T  0.822964 -10.0  SNP
# jcf7190000000000-77657  jcf7190000000000  77657   T   C  0.808995 -10.0  SNP
# jcf7190000000000-77738  jcf7190000000000  77738   T   C  0.804214 -10.0  SNP
# jcf7190000000000-77764  jcf7190000000000  77764   T   C  0.933934 -10.0  SNP
# jcf7190000000000-77784  jcf7190000000000  77784   A   G  0.904187 -10.0  SNP
#
#                        FILTER  ADP  WT  HET  HOM  NC DF_p18.GT  DF_p18.GQ  \
# jcf7190000000000-77602   PASS   11   6   34   26  21       G/T       84.0
# jcf7190000000000-77657   PASS   16   5   51   26   5       C/C      160.0
# jcf7190000000000-77738   PASS   13   2   49   28   8       T/C      103.0
# jcf7190000000000-77764   PASS   12   1   28   50   8       C/C      127.0
# jcf7190000000000-77784   PASS   11   0   32   38  17       G/G      107.0
#
#                         DF_p18.SDP  DF_p18.DP DF_p18.FREQ   DF_p18.PVAL  \
# jcf7190000000000-77602          24       24.0      79.17%  3.682600e-09
# jcf7190000000000-77657          43       43.0       81.4%  9.593300e-17
# jcf7190000000000-77738          32       32.0         75%  4.196400e-11
# jcf7190000000000-77764          29       29.0      89.66%  1.649600e-13
# jcf7190000000000-77784          27       27.0      85.19%  1.616100e-11
#
#                         DF_p18.AD  DF_p18.RD DF_p19.GT  DF_p19.GQ  DF_p19.SDP  \
# jcf7190000000000-77602       19.0        5.0       T/T      121.0          26
# jcf7190000000000-77657       35.0        8.0       C/C      128.0          34
# jcf7190000000000-77738       24.0        8.0       C/C      126.0          27
# jcf7190000000000-77764       26.0        3.0       C/C      117.0          21
# jcf7190000000000-77784       23.0        4.0       G/G      111.0          20
#
#                         DF_p19.DP DF_p19.FREQ   DF_p19.PVAL  DF_p19.AD  \
# jcf7190000000000-77602       26.0      92.31%  7.622200e-13       24.0
# jcf7190000000000-77657       34.0      82.35%  1.349000e-13       28.0
# jcf7190000000000-77738       27.0      92.59%  2.085300e-13       25.0
# jcf7190000000000-77764       21.0        100%  1.857800e-12       21.0
# jcf7190000000000-77784       20.0        100%  7.254400e-12       20.0
#
#                         DF_p19.RD DF_p20.GT  DF_p20.GQ  DF_p20.SDP  DF_p20.DP  \
# jcf7190000000000-77602        2.0       ./.        NaN           2        NaN
# jcf7190000000000-77657        6.0       ./.        NaN           3        NaN
# jcf7190000000000-77738        2.0       ./.        NaN           3        NaN
# jcf7190000000000-77764        0.0       ./.        NaN           4        NaN
# jcf7190000000000-77784        0.0       ./.        NaN           3        NaN
#
#                        DF_p20.FREQ  DF_p20.PVAL  DF_p20.AD  DF_p20.RD  \
# jcf7190000000000-77602         NaN          NaN        NaN        NaN
# jcf7190000000000-77657         NaN          NaN        NaN        NaN
# jcf7190000000000-77738         NaN          NaN        NaN        NaN
# jcf7190000000000-77764         NaN          NaN        NaN        NaN
# jcf7190000000000-77784         NaN          NaN        NaN        NaN
#
#                        DF_p3.GT  DF_p3.GQ  DF_p3.SDP  DF_p3.DP DF_p3.FREQ  \
# jcf7190000000000-77602      T/T      87.0         20      20.0        90%
# jcf7190000000000-77657      C/C      71.0         20      20.0        80%
# jcf7190000000000-77738      C/C      76.0         18      18.0     88.89%
# jcf7190000000000-77764      C/C      76.0         14      14.0       100%
# jcf7190000000000-77784      G/G      64.0         12      12.0       100%
#
#                           DF_p3.PVAL  DF_p3.AD  DF_p3.RD DF_p33.GT  DF_p33.GQ  \
# jcf7190000000000-77602  1.675800e-09      18.0       2.0       ./.        NaN
# jcf7190000000000-77657  7.708600e-08      16.0       4.0       C/C       47.0
# jcf7190000000000-77738  2.093600e-08      16.0       2.0       T/C       29.0
# jcf7190000000000-77764  2.492700e-08      14.0       0.0       C/C       58.0
# jcf7190000000000-77784  3.698000e-07      12.0       0.0       G/G       46.0
#
#                         DF_p33.SDP  DF_p33.DP DF_p33.FREQ  ...  DF_p86.GT  \
# jcf7190000000000-77602           5        NaN         NaN  ...        G/T
# jcf7190000000000-77657          11       11.0      90.91%  ...        C/C
# jcf7190000000000-77738           9        9.0      77.78%  ...        C/C
# jcf7190000000000-77764          11       11.0        100%  ...        C/C
# jcf7190000000000-77784           9        9.0        100%  ...        G/G
#
#                         DF_p86.GQ  DF_p86.SDP DF_p86.DP  DF_p86.FREQ  \
# jcf7190000000000-77602       29.0           9       9.0       77.78%
# jcf7190000000000-77657       68.0          18      18.0       83.33%
# jcf7190000000000-77738       71.0          18      18.0       88.24%
# jcf7190000000000-77764       71.0          17      17.0       88.24%
# jcf7190000000000-77784       49.0          13      13.0       84.62%
#
#                          DF_p86.PVAL  DF_p86.AD DF_p86.RD  DF_p87.GT  \
# jcf7190000000000-77602  1.131200e-03        7.0       2.0        T/T
# jcf7190000000000-77657  1.465500e-07       15.0       3.0        C/C
# jcf7190000000000-77738  7.327700e-08       15.0       3.0        C/C
# jcf7190000000000-77764  7.327700e-08       15.0       2.0        C/C
# jcf7190000000000-77784  1.009600e-05       11.0       2.0        G/G
#
#                         DF_p87.GQ  DF_p87.SDP DF_p87.DP  DF_p87.FREQ  \
# jcf7190000000000-77602       44.0          12      12.0       83.33%
# jcf7190000000000-77657       81.0          17      17.0       94.12%
# jcf7190000000000-77738       52.0          10      10.0         100%
# jcf7190000000000-77764       52.0          10      10.0         100%
# jcf7190000000000-77784       41.0           8       8.0         100%
#
#                          DF_p87.PVAL  DF_p87.AD DF_p87.RD  DF_p88.GT  \
# jcf7190000000000-77602  3.365200e-05       10.0       2.0        T/T
# jcf7190000000000-77657  7.713400e-09       16.0       1.0        C/C
# jcf7190000000000-77738  5.412500e-06       10.0       0.0        ./.
# jcf7190000000000-77764  5.412500e-06       10.0       0.0        C/C
# jcf7190000000000-77784  7.770000e-05        8.0       0.0        G/G
#
#                         DF_p88.GQ  DF_p88.SDP DF_p88.DP  DF_p88.FREQ  \
# jcf7190000000000-77602       52.0          10      10.0         100%
# jcf7190000000000-77657       60.0          15      15.0       86.67%
# jcf7190000000000-77738        NaN           7       NaN          NaN
# jcf7190000000000-77764       36.0           9       9.0       88.89%
# jcf7190000000000-77784       46.0           9       9.0         100%
#
#                          DF_p88.PVAL  DF_p88.AD DF_p88.RD  DF_p89.GT  \
# jcf7190000000000-77602  5.412500e-06       10.0       0.0        T/T
# jcf7190000000000-77657  8.767500e-07       13.0       2.0        T/C
# jcf7190000000000-77738           NaN        NaN       NaN        C/C
# jcf7190000000000-77764  2.056800e-04        8.0       1.0        C/C
# jcf7190000000000-77784  2.056800e-05        9.0       0.0        G/G
#
#                         DF_p89.GQ  DF_p89.SDP DF_p89.DP  DF_p89.FREQ  \
# jcf7190000000000-77602       52.0          15      15.0          80%
# jcf7190000000000-77657       79.0          23      23.0       78.26%
# jcf7190000000000-77738      105.0          25      25.0          88%
# jcf7190000000000-77764       86.0          18      18.0       94.44%
# jcf7190000000000-77784       34.0          10      10.0          80%
#
#                          DF_p89.PVAL  DF_p89.AD DF_p89.RD  DF_p9.GT  DF_p9.GQ  \
# jcf7190000000000-77602  5.260500e-06       12.0       3.0       T/T      39.0
# jcf7190000000000-77657  1.193700e-08       18.0       5.0       T/C      49.0
# jcf7190000000000-77738  2.591600e-11       22.0       3.0       T/C      18.0
# jcf7190000000000-77764  2.093600e-09       17.0       1.0       C/C      52.0
# jcf7190000000000-77784  3.572300e-04        8.0       2.0       G/G      46.0
#
#                         DF_p9.SDP DF_p9.DP  DF_p9.FREQ  DF_p9.PVAL  DF_p9.AD  \
# jcf7190000000000-77602         11     11.0      81.82%    0.000111       9.0
# jcf7190000000000-77657         17     17.0      70.59%    0.000011      12.0
# jcf7190000000000-77738          9      9.0         NaN    0.014706       5.0
# jcf7190000000000-77764         10     10.0        100%    0.000005      10.0
# jcf7190000000000-77784          9      9.0        100%    0.000021       9.0
#
#                        DF_p9.RD  DF_p94.GT  DF_p94.GQ  DF_p94.SDP DF_p94.DP  \
# jcf7190000000000-77602      2.0        G/T       31.0          12      12.0
# jcf7190000000000-77657      5.0        T/C       60.0          18      18.0
# jcf7190000000000-77738      4.0        C/C       55.0          14      14.0
# jcf7190000000000-77764      0.0        C/C       52.0          10      10.0
# jcf7190000000000-77784      0.0        A/G       37.0          12      12.0
#
#                         DF_p94.FREQ   DF_p94.PVAL  DF_p94.AD DF_p94.RD  \
# jcf7190000000000-77602       66.67%  6.730400e-04        8.0       4.0
# jcf7190000000000-77657       77.78%  8.060500e-07       14.0       4.0
# jcf7190000000000-77738       85.71%  2.991300e-06       12.0       2.0
# jcf7190000000000-77764         100%  5.412500e-06       10.0       0.0
# jcf7190000000000-77784          75%  1.682600e-04        9.0       3.0
#
#                                          locus       MAF
# jcf7190000000000-77602  jcf7190000000000-77602  0.177036
# jcf7190000000000-77657  jcf7190000000000-77657  0.191005
# jcf7190000000000-77738  jcf7190000000000-77738  0.195786
# jcf7190000000000-77764  jcf7190000000000-77764  0.066066
# jcf7190000000000-77784  jcf7190000000000-77784  0.095813
#
# [5 rows x 351 columns]

# %%
snps.shape
# Out:
# (2609583, 351)

# %%
# reduce snps to those with ADP < 1000
reduced = snps[snps['ADP'] < 1000].copy()
reduced.shape, snps.shape
# Out:
# ((2609304, 351), (2609583, 351))

# %%
# test function
x = get_counts(reduced.index[:5])
x.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
#                         DF_p18-major  DF_p18-minor  DF_p19-major  \
# jcf7190000000000-77602            19             5            24
# jcf7190000000000-77657            35             8            28
# jcf7190000000000-77738            24             8            25
# jcf7190000000000-77764            26             3            21
# jcf7190000000000-77784            23             4            20
#
#                         DF_p19-minor  DF_p20-major  DF_p20-minor  DF_p3-major  \
# jcf7190000000000-77602             2             0             0           18
# jcf7190000000000-77657             6             0             0           16
# jcf7190000000000-77738             2             0             0           16
# jcf7190000000000-77764             0             0             0           14
# jcf7190000000000-77784             0             0             0           12
#
#                         DF_p3-minor  DF_p33-major  DF_p33-minor  DF_p34-major  \
# jcf7190000000000-77602            2             0             0            13
# jcf7190000000000-77657            4            10             1            19
# jcf7190000000000-77738            2             7             2            12
# jcf7190000000000-77764            0            11             0            18
# jcf7190000000000-77784            0             9             0            12
#
#                         DF_p34-minor  DF_p35-major  DF_p35-minor  \
# jcf7190000000000-77602             0             9             3
# jcf7190000000000-77657             5             9             4
# jcf7190000000000-77738             6             6             2
# jcf7190000000000-77764             0            11             0
# jcf7190000000000-77784             0             8             0
#
#                         DF_p36-major  DF_p36-minor  DF_p37-major  \
# jcf7190000000000-77602            14             1             9
# jcf7190000000000-77657            14             2             7
# jcf7190000000000-77738            11             2             9
# jcf7190000000000-77764             9             0             0
# jcf7190000000000-77784            10             0             0
#
#                         DF_p37-minor  DF_p38-major  DF_p38-minor  \
# jcf7190000000000-77602             2            21             3
# jcf7190000000000-77657             4            20             4
# jcf7190000000000-77738             1            15             2
# jcf7190000000000-77764             0            13             1
# jcf7190000000000-77784             0            16             0
#
#                         DF_p39-major  DF_p39-minor  DF_p4-major  DF_p4-minor  \
# jcf7190000000000-77602            16             3           14            2
# jcf7190000000000-77657            21             2           10            2
# jcf7190000000000-77738            10             2            9            2
# jcf7190000000000-77764            12             1           11            0
# jcf7190000000000-77784            11             2            7            1
#
#                         DF_p40-major  DF_p40-minor  DF_p41-major  \
# jcf7190000000000-77602             0             0             0
# jcf7190000000000-77657             0             0             8
# jcf7190000000000-77738             0             0             6
# jcf7190000000000-77764             0             0             8
# jcf7190000000000-77784             0             0             0
#
#                         DF_p41-minor  DF_p42-major  DF_p42-minor  \
# jcf7190000000000-77602             0             6             2
# jcf7190000000000-77657             6             7             2
# jcf7190000000000-77738             5             6             3
# jcf7190000000000-77764             1             7             2
# jcf7190000000000-77784             0             6             2
#
#                         DF_p43-major  DF_p43-minor  DF_p44-major  \
# jcf7190000000000-77602            13             6            15
# jcf7190000000000-77657            15             8            16
# jcf7190000000000-77738            10             7            10
# jcf7190000000000-77764            10             6            14
# jcf7190000000000-77784            12             7            12
#
#                         DF_p44-minor  DF_p45-major  DF_p45-minor  \
# jcf7190000000000-77602             1            11             2
# jcf7190000000000-77657             5            15             2
# jcf7190000000000-77738             5            11             4
# jcf7190000000000-77764             2            11             1
# jcf7190000000000-77784             2            13             1
#
#                         DF_p46-major  DF_p46-minor  DF_p47-major  \
# jcf7190000000000-77602            12             1             0
# jcf7190000000000-77657            15             6             0
# jcf7190000000000-77738             6             2             0
# jcf7190000000000-77764             0             0             0
# jcf7190000000000-77784             0             0             0
#
#                         DF_p47-minor  DF_p48-major  DF_p48-minor  \
# jcf7190000000000-77602             0             6             3
# jcf7190000000000-77657             0             9             2
# jcf7190000000000-77738             0             7             3
# jcf7190000000000-77764             0             7             1
# jcf7190000000000-77784             0             0             0
#
#                         DF_p49-major  DF_p49-minor  DF_p5-major  DF_p5-minor  \
# jcf7190000000000-77602            11             4           21            2
# jcf7190000000000-77657            14             0           21            4
# jcf7190000000000-77738            11             0           15            3
# jcf7190000000000-77764             9             0           14            0
# jcf7190000000000-77784             9             1           13            0
#
#                         DF_p54-major  DF_p54-minor  DF_p55-major  \
# jcf7190000000000-77602            13             5             7
# jcf7190000000000-77657            22             3            13
# jcf7190000000000-77738            15             5             9
# jcf7190000000000-77764            16             0            10
# jcf7190000000000-77784            12             1             8
#
#                         DF_p55-minor  DF_p56-major  DF_p56-minor  \
# jcf7190000000000-77602             8             0             0
# jcf7190000000000-77657             4             8             2
# jcf7190000000000-77738             3             6             4
# jcf7190000000000-77764             2            12             0
# jcf7190000000000-77784             4            10             1
#
#                         DF_p57-major  DF_p57-minor  DF_p58-major  \
# jcf7190000000000-77602            11             2             7
# jcf7190000000000-77657            16             4             9
# jcf7190000000000-77738            12             1            11
# jcf7190000000000-77764            11             0            15
# jcf7190000000000-77784            10             1            14
#
#                         DF_p58-minor  DF_p59-major  DF_p59-minor  DF_p6-major  \
# jcf7190000000000-77602             1             0             0            0
# jcf7190000000000-77657             4            10             1            0
# jcf7190000000000-77738             3             9             3            0
# jcf7190000000000-77764             1            10             2            0
# jcf7190000000000-77784             2             7             1            0
#
#                         DF_p6-minor  DF_p60-major  DF_p60-minor  DF_p61-major  \
# jcf7190000000000-77602            0            13             0            21
# jcf7190000000000-77657            0            16             6            22
# jcf7190000000000-77738            0            15             2            13
# jcf7190000000000-77764            0            12             0            14
# jcf7190000000000-77784            0             9             0            13
#
#                         DF_p61-minor  DF_p62-major  DF_p62-minor  DF_p7-major  \
# jcf7190000000000-77602             5            14             6            0
# jcf7190000000000-77657             8            17             2           16
# jcf7190000000000-77738             4            13             1           14
# jcf7190000000000-77764             2            14             0           11
# jcf7190000000000-77784             1            15             0           11
#
#                         DF_p7-minor  DF_p8-major  DF_p8-minor  DF_p85-major  \
# jcf7190000000000-77602            0           12            2             9
# jcf7190000000000-77657            2           19            2            17
# jcf7190000000000-77738            3           14            0            16
# jcf7190000000000-77764            2           11            0            14
# jcf7190000000000-77784            1            0            0            12
#
#                         DF_p85-minor  DF_p86-major  DF_p86-minor  \
# jcf7190000000000-77602             2             7             2
# jcf7190000000000-77657             2            15             3
# jcf7190000000000-77738             3            15             3
# jcf7190000000000-77764             2            15             2
# jcf7190000000000-77784             3            11             2
#
#                         DF_p87-major  DF_p87-minor  DF_p88-major  \
# jcf7190000000000-77602            10             2            10
# jcf7190000000000-77657            16             1            13
# jcf7190000000000-77738            10             0             0
# jcf7190000000000-77764            10             0             8
# jcf7190000000000-77784             8             0             9
#
#                         DF_p88-minor  DF_p89-major  DF_p89-minor  DF_p9-major  \
# jcf7190000000000-77602             0            12             3            9
# jcf7190000000000-77657             2            18             5           12
# jcf7190000000000-77738             0            22             3            0
# jcf7190000000000-77764             1            17             1           10
# jcf7190000000000-77784             0             8             2            9
#
#                         DF_p9-minor  DF_p94-major  DF_p94-minor
# jcf7190000000000-77602            2             8             4
# jcf7190000000000-77657            5            14             4
# jcf7190000000000-77738            0            12             2
# jcf7190000000000-77764            0            10             0
# jcf7190000000000-77784            0             9             3

# %%
# get a list of cols necessary for get_counts() to save mem on engines
important_cols = [col for col in reduced.columns if '.FREQ' in col]
important_cols.extend([col for col in reduced.columns if 'AD' in col or 'RD' in col])
important_cols.extend(['AF', 'MAF'])
len(important_cols)
# Out:
# 129

# %%
# restart engines
lview,dview = get_client()
# Out:
# 15 15

# %%
# load reduced to engines, but only important columns
dview['reduced'] = reduced[important_cols]

# %%
# thresh to evenly distribute jobs
nrow(reduced) / len(lview)
# Out:
# 173953.6

# %%
# send jobs to engines for get_counts()
jobs = []
tosend = []
for i,locus in enumerate(reduced.index):
    tosend.append(locus)
    if len(tosend) == 173954 or (i+1)==nrow(reduced):
        jobs.append(lview.apply_async(get_counts, tosend))
        tosend = []
watch_async(jobs)
# Out:
# 15
# 15

# %%
# get jobs returns
gfile = pd.concat([j.r for j in jobs])

# %%
# make sure returns make sense
nrow(reduced) == nrow(gfile)
# Out:
# True

# %%
# make sure returns make sense
nrow(reduced) == luni(gfile.index)
# Out:
# True

# %%
baydir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass'

# %%
def write_file(df, filepath):
    import pandas
    if 'noheader' in filepath:
        index=False
        header=False
    else:
        index = True
        header=True
    df.to_csv(filepath, sep='\t', header=header, index=index)
    return filepath

# %%
jobs = []
files = [op.join(baydir, 'interior_all_snps_ADP-lt-1000_gfile_HEADERIDX.txt'),
         op.join(baydir, 'interior_all_snps_ADP-lt-1000_gfile_noheaderidx.txt')]
for f in files:
    jobs.append(lview.apply_async(write_file, *(gfile, f)))

# %%
watch_async(jobs)

# %%
baydir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass'

# %%
nrow(reduced)/10000
# Out:
# 260.9304

# %%
gfile_dir = makedir(op.join(baydir, 'individual_gfiles'))

# %%
gfile_dir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/individual_gfiles'

# %%
gfile = pd.read_table('/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/interior_all_snps_ADP-lt-1000_gfile_HEADERIDX.txt',
                      index_col=0)
gfile.head()
# Out:
#                         DF_p18-major  DF_p18-minor  DF_p19-major  \
# jcf7190000000000-77602            19             5            24
# jcf7190000000000-77657            35             8            28
# jcf7190000000000-77738            24             8            25
# jcf7190000000000-77764            26             3            21
# jcf7190000000000-77784            23             4            20
#
#                         DF_p19-minor  DF_p20-major  DF_p20-minor  DF_p3-major  \
# jcf7190000000000-77602             2             0             0           18
# jcf7190000000000-77657             6             0             0           16
# jcf7190000000000-77738             2             0             0           16
# jcf7190000000000-77764             0             0             0           14
# jcf7190000000000-77784             0             0             0           12
#
#                         DF_p3-minor  DF_p33-major  DF_p33-minor  DF_p34-major  \
# jcf7190000000000-77602            2             0             0            13
# jcf7190000000000-77657            4            10             1            19
# jcf7190000000000-77738            2             7             2            12
# jcf7190000000000-77764            0            11             0            18
# jcf7190000000000-77784            0             9             0            12
#
#                         DF_p34-minor  DF_p35-major  DF_p35-minor  \
# jcf7190000000000-77602             0             9             3
# jcf7190000000000-77657             5             9             4
# jcf7190000000000-77738             6             6             2
# jcf7190000000000-77764             0            11             0
# jcf7190000000000-77784             0             8             0
#
#                         DF_p36-major  DF_p36-minor  DF_p37-major  \
# jcf7190000000000-77602            14             1             9
# jcf7190000000000-77657            14             2             7
# jcf7190000000000-77738            11             2             9
# jcf7190000000000-77764             9             0             0
# jcf7190000000000-77784            10             0             0
#
#                         DF_p37-minor  DF_p38-major  DF_p38-minor  \
# jcf7190000000000-77602             2            21             3
# jcf7190000000000-77657             4            20             4
# jcf7190000000000-77738             1            15             2
# jcf7190000000000-77764             0            13             1
# jcf7190000000000-77784             0            16             0
#
#                         DF_p39-major  DF_p39-minor  DF_p4-major  DF_p4-minor  \
# jcf7190000000000-77602            16             3           14            2
# jcf7190000000000-77657            21             2           10            2
# jcf7190000000000-77738            10             2            9            2
# jcf7190000000000-77764            12             1           11            0
# jcf7190000000000-77784            11             2            7            1
#
#                         DF_p40-major  DF_p40-minor  DF_p41-major  \
# jcf7190000000000-77602             0             0             0
# jcf7190000000000-77657             0             0             8
# jcf7190000000000-77738             0             0             6
# jcf7190000000000-77764             0             0             8
# jcf7190000000000-77784             0             0             0
#
#                         DF_p41-minor  DF_p42-major  DF_p42-minor  \
# jcf7190000000000-77602             0             6             2
# jcf7190000000000-77657             6             7             2
# jcf7190000000000-77738             5             6             3
# jcf7190000000000-77764             1             7             2
# jcf7190000000000-77784             0             6             2
#
#                         DF_p43-major  DF_p43-minor  DF_p44-major  \
# jcf7190000000000-77602            13             6            15
# jcf7190000000000-77657            15             8            16
# jcf7190000000000-77738            10             7            10
# jcf7190000000000-77764            10             6            14
# jcf7190000000000-77784            12             7            12
#
#                         DF_p44-minor  DF_p45-major  DF_p45-minor  \
# jcf7190000000000-77602             1            11             2
# jcf7190000000000-77657             5            15             2
# jcf7190000000000-77738             5            11             4
# jcf7190000000000-77764             2            11             1
# jcf7190000000000-77784             2            13             1
#
#                         DF_p46-major  DF_p46-minor  DF_p47-major  \
# jcf7190000000000-77602            12             1             0
# jcf7190000000000-77657            15             6             0
# jcf7190000000000-77738             6             2             0
# jcf7190000000000-77764             0             0             0
# jcf7190000000000-77784             0             0             0
#
#                         DF_p47-minor  DF_p48-major  DF_p48-minor  \
# jcf7190000000000-77602             0             6             3
# jcf7190000000000-77657             0             9             2
# jcf7190000000000-77738             0             7             3
# jcf7190000000000-77764             0             7             1
# jcf7190000000000-77784             0             0             0
#
#                         DF_p49-major  DF_p49-minor  DF_p5-major  DF_p5-minor  \
# jcf7190000000000-77602            11             4           21            2
# jcf7190000000000-77657            14             0           21            4
# jcf7190000000000-77738            11             0           15            3
# jcf7190000000000-77764             9             0           14            0
# jcf7190000000000-77784             9             1           13            0
#
#                         DF_p54-major  DF_p54-minor  DF_p55-major  \
# jcf7190000000000-77602            13             5             7
# jcf7190000000000-77657            22             3            13
# jcf7190000000000-77738            15             5             9
# jcf7190000000000-77764            16             0            10
# jcf7190000000000-77784            12             1             8
#
#                         DF_p55-minor  DF_p56-major  DF_p56-minor  \
# jcf7190000000000-77602             8             0             0
# jcf7190000000000-77657             4             8             2
# jcf7190000000000-77738             3             6             4
# jcf7190000000000-77764             2            12             0
# jcf7190000000000-77784             4            10             1
#
#                         DF_p57-major  DF_p57-minor  DF_p58-major  \
# jcf7190000000000-77602            11             2             7
# jcf7190000000000-77657            16             4             9
# jcf7190000000000-77738            12             1            11
# jcf7190000000000-77764            11             0            15
# jcf7190000000000-77784            10             1            14
#
#                         DF_p58-minor  DF_p59-major  DF_p59-minor  DF_p6-major  \
# jcf7190000000000-77602             1             0             0            0
# jcf7190000000000-77657             4            10             1            0
# jcf7190000000000-77738             3             9             3            0
# jcf7190000000000-77764             1            10             2            0
# jcf7190000000000-77784             2             7             1            0
#
#                         DF_p6-minor  DF_p60-major  DF_p60-minor  DF_p61-major  \
# jcf7190000000000-77602            0            13             0            21
# jcf7190000000000-77657            0            16             6            22
# jcf7190000000000-77738            0            15             2            13
# jcf7190000000000-77764            0            12             0            14
# jcf7190000000000-77784            0             9             0            13
#
#                         DF_p61-minor  DF_p62-major  DF_p62-minor  DF_p7-major  \
# jcf7190000000000-77602             5            14             6            0
# jcf7190000000000-77657             8            17             2           16
# jcf7190000000000-77738             4            13             1           14
# jcf7190000000000-77764             2            14             0           11
# jcf7190000000000-77784             1            15             0           11
#
#                         DF_p7-minor  DF_p8-major  DF_p8-minor  DF_p85-major  \
# jcf7190000000000-77602            0           12            2             9
# jcf7190000000000-77657            2           19            2            17
# jcf7190000000000-77738            3           14            0            16
# jcf7190000000000-77764            2           11            0            14
# jcf7190000000000-77784            1            0            0            12
#
#                         DF_p85-minor  DF_p86-major  DF_p86-minor  \
# jcf7190000000000-77602             2             7             2
# jcf7190000000000-77657             2            15             3
# jcf7190000000000-77738             3            15             3
# jcf7190000000000-77764             2            15             2
# jcf7190000000000-77784             3            11             2
#
#                         DF_p87-major  DF_p87-minor  DF_p88-major  \
# jcf7190000000000-77602            10             2            10
# jcf7190000000000-77657            16             1            13
# jcf7190000000000-77738            10             0             0
# jcf7190000000000-77764            10             0             8
# jcf7190000000000-77784             8             0             9
#
#                         DF_p88-minor  DF_p89-major  DF_p89-minor  DF_p9-major  \
# jcf7190000000000-77602             0            12             3            9
# jcf7190000000000-77657             2            18             5           12
# jcf7190000000000-77738             0            22             3            0
# jcf7190000000000-77764             1            17             1           10
# jcf7190000000000-77784             0             8             2            9
#
#                         DF_p9-minor  DF_p94-major  DF_p94-minor
# jcf7190000000000-77602            2             8             4
# jcf7190000000000-77657            5            14             4
# jcf7190000000000-77738            0            12             2
# jcf7190000000000-77764            0            10             0
# jcf7190000000000-77784            0             9             3

# %%
# write small gfiles to parallelize baypass
newjobs = []
tosend = []
jobcount = 0
for i,locus in enumerate(gfile.index):
    tosend.append(locus)
    if len(tosend) == 2500 or (i+1) == len(gfile.index):
        smallgfile = gfile.loc[tosend, :].copy()
        for bname in ['interior_all_snps_ADP-lt-1000_gfile_HEADERIDX.txt',
                      'interior_all_snps_ADP-lt-1000_gfile_noheaderidx.txt']:
            bname = bname.replace('_gfile', '_gfile_%s' % str(jobcount).zfill(4))  # I changed this line
            smallpath = op.join(gfile_dir, bname)
            newjobs.append(lview.apply_async(write_file, *(smallgfile, smallpath)))
        tosend = []
        jobcount += 1
watch_async(newjobs)
# Out:
# 2088
# 2088

# %%
smallgfile.head()
# Out:
#                        DF_p18-major  DF_p18-minor  DF_p19-major  DF_p19-minor  \
# jcf7190016524026-2949            49             4            78             2
# jcf7190016524026-2958            38            15            36            31
# jcf7190016524026-2982            34            15            37            21
# jcf7190016524026-2986            46             2            56             0
# jcf7190016524026-3000            46             2            44             2
#
#                        DF_p20-major  DF_p20-minor  DF_p3-major  DF_p3-minor  \
# jcf7190016524026-2949            27             2           48            1
# jcf7190016524026-2958            18             8           32           16
# jcf7190016524026-2982             8            16           36           12
# jcf7190016524026-2986            24             1           41            4
# jcf7190016524026-3000            27             0           38            0
#
#                        DF_p33-major  DF_p33-minor  DF_p34-major  DF_p34-minor  \
# jcf7190016524026-2949            61             7            41             3
# jcf7190016524026-2958            45            15            24            18
# jcf7190016524026-2982            32            27            27            11
# jcf7190016524026-2986            53             3            37             1
# jcf7190016524026-3000            41             4            30             2
#
#                        DF_p35-major  DF_p35-minor  DF_p36-major  DF_p36-minor  \
# jcf7190016524026-2949            65             4            41             3
# jcf7190016524026-2958            34            30             0             0
# jcf7190016524026-2982            40            17             7            28
# jcf7190016524026-2986            55             2             0             0
# jcf7190016524026-3000            48             2            29             1
#
#                        DF_p37-major  DF_p37-minor  DF_p38-major  DF_p38-minor  \
# jcf7190016524026-2949            35             3            62             0
# jcf7190016524026-2958            19            13            37            22
# jcf7190016524026-2982            17            11            40            10
# jcf7190016524026-2986            22             4            49             0
# jcf7190016524026-3000            22             2            44             0
#
#                        DF_p39-major  DF_p39-minor  DF_p4-major  DF_p4-minor  \
# jcf7190016524026-2949            50             1           36            3
# jcf7190016524026-2958            32             8           28           11
# jcf7190016524026-2982            25            13           23           18
# jcf7190016524026-2986            32             0            0            0
# jcf7190016524026-3000            29             0           41            1
#
#                        DF_p40-major  DF_p40-minor  DF_p41-major  DF_p41-minor  \
# jcf7190016524026-2949            27             1            37             1
# jcf7190016524026-2958            19            10            26            11
# jcf7190016524026-2982            16            13            18            17
# jcf7190016524026-2986            25             3            31             1
# jcf7190016524026-3000            24             1            29             1
#
#                        DF_p42-major  DF_p42-minor  DF_p43-major  DF_p43-minor  \
# jcf7190016524026-2949            28             4            47             1
# jcf7190016524026-2958            16            13            31            11
# jcf7190016524026-2982            15            10            33            17
# jcf7190016524026-2986            23             1            48             1
# jcf7190016524026-3000             0             0            53             1
#
#                        DF_p44-major  DF_p44-minor  DF_p45-major  DF_p45-minor  \
# jcf7190016524026-2949            40             2            55             3
# jcf7190016524026-2958            30            15            41            14
# jcf7190016524026-2982            26            18            36            22
# jcf7190016524026-2986            42             1            55             2
# jcf7190016524026-3000            40             3            50             2
#
#                        DF_p46-major  DF_p46-minor  DF_p47-major  DF_p47-minor  \
# jcf7190016524026-2949            49             4            54             7
# jcf7190016524026-2958            29            23            38            18
# jcf7190016524026-2982            31            18            26            24
# jcf7190016524026-2986            45             2            44             2
# jcf7190016524026-3000            37             4            36             7
#
#                        DF_p48-major  DF_p48-minor  DF_p49-major  DF_p49-minor  \
# jcf7190016524026-2949            31             0             0             0
# jcf7190016524026-2958             0             0            50            11
# jcf7190016524026-2982            18             9            33            22
# jcf7190016524026-2986            26             1            47             4
# jcf7190016524026-3000            29             1            46             4
#
#                        DF_p5-major  DF_p5-minor  DF_p54-major  DF_p54-minor  \
# jcf7190016524026-2949           43            4            68             0
# jcf7190016524026-2958           38            7            44            13
# jcf7190016524026-2982           27           17            36            16
# jcf7190016524026-2986            0            0            44             4
# jcf7190016524026-3000           38            1            42             0
#
#                        DF_p55-major  DF_p55-minor  DF_p56-major  DF_p56-minor  \
# jcf7190016524026-2949            45             2            42             3
# jcf7190016524026-2958            27            13            25            16
# jcf7190016524026-2982            20            15            26            13
# jcf7190016524026-2986            33             1            37             1
# jcf7190016524026-3000            25             3            32             4
#
#                        DF_p57-major  DF_p57-minor  DF_p58-major  DF_p58-minor  \
# jcf7190016524026-2949            35             2            55             3
# jcf7190016524026-2958            23            13            39            16
# jcf7190016524026-2982            20            16            33            19
# jcf7190016524026-2986            32             4            48             4
# jcf7190016524026-3000            30             2            51             3
#
#                        DF_p59-major  DF_p59-minor  DF_p6-major  DF_p6-minor  \
# jcf7190016524026-2949            41             2           46            0
# jcf7190016524026-2958            25            16           36            9
# jcf7190016524026-2982            24            15           35            8
# jcf7190016524026-2986            34             3           41            1
# jcf7190016524026-3000            35             1           43            0
#
#                        DF_p60-major  DF_p60-minor  DF_p61-major  DF_p61-minor  \
# jcf7190016524026-2949            57             1            64             2
# jcf7190016524026-2958            41            18            43            25
# jcf7190016524026-2982            30            22            37            28
# jcf7190016524026-2986            47             4            59             4
# jcf7190016524026-3000            52             1             0             0
#
#                        DF_p62-major  DF_p62-minor  DF_p7-major  DF_p7-minor  \
# jcf7190016524026-2949            60            11           54            2
# jcf7190016524026-2958            50            19           35           14
# jcf7190016524026-2982            42            30           23           22
# jcf7190016524026-2986            68             4           42            2
# jcf7190016524026-3000            52            13           36            3
#
#                        DF_p8-major  DF_p8-minor  DF_p85-major  DF_p85-minor  \
# jcf7190016524026-2949           48            9             0             0
# jcf7190016524026-2958           43           14            47            14
# jcf7190016524026-2982           20           26            31            20
# jcf7190016524026-2986            0            0            48             2
# jcf7190016524026-3000           39            4            43             2
#
#                        DF_p86-major  DF_p86-minor  DF_p87-major  DF_p87-minor  \
# jcf7190016524026-2949            39             0             0             0
# jcf7190016524026-2958            28            10            30            18
# jcf7190016524026-2982            23             8            24            17
# jcf7190016524026-2986            32             1            32             9
# jcf7190016524026-3000            34             3            33             4
#
#                        DF_p88-major  DF_p88-minor  DF_p89-major  DF_p89-minor  \
# jcf7190016524026-2949             0             0            37             2
# jcf7190016524026-2958            31            11            26            12
# jcf7190016524026-2982            27            14            27             8
# jcf7190016524026-2986            40             2            33             2
# jcf7190016524026-3000            36             1            33             1
#
#                        DF_p9-major  DF_p9-minor  DF_p94-major  DF_p94-minor
# jcf7190016524026-2949           52            2            50             1
# jcf7190016524026-2958           37           13            40            11
# jcf7190016524026-2982           32           14            28            18
# jcf7190016524026-2986           42            3            42             4
# jcf7190016524026-3000           42            1            41             1

# %%
# compare columns to small gfile
poolsizefile
# Out:
#    DF_p18  DF_p19  DF_p20  DF_p3  DF_p33  DF_p34  DF_p35  DF_p36  DF_p37  \
# 0      80      80      80     80      80      78      80      80      74
#
#    DF_p38  DF_p39  DF_p4  DF_p40  DF_p41  DF_p42  DF_p43  DF_p44  DF_p45  \
# 0      80      80     80      80      80      80      80      80      80
#
#    DF_p46  DF_p47  DF_p48  DF_p49  DF_p5  DF_p54  DF_p55  DF_p56  DF_p57  \
# 0      80      80      80      80     80      70      80      80      80
#
#    DF_p58  DF_p59  DF_p6  DF_p60  DF_p61  DF_p62  DF_p7  DF_p8  DF_p85  \
# 0      76      74     80      80      78      80     80     80      80
#
#    DF_p86  DF_p87  DF_p88  DF_p89  DF_p9  DF_p94
# 0      80      80      80      80     80      80

# %%
gfile_dir = '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/individual_gfiles'

# %%
from pythonimports import *

# %%
smallgfile = pd.read_table(fs(gfile_dir, 'HEADER')[0], index_col=0)
smallgfile.head()
# Out:
#                         DF_p18-major  DF_p18-minor  DF_p19-major  \
# jcf7190000000000-77602            19             5            24
# jcf7190000000000-77657            35             8            28
# jcf7190000000000-77738            24             8            25
# jcf7190000000000-77764            26             3            21
# jcf7190000000000-77784            23             4            20
#
#                         DF_p19-minor  DF_p20-major  DF_p20-minor  DF_p3-major  \
# jcf7190000000000-77602             2             0             0           18
# jcf7190000000000-77657             6             0             0           16
# jcf7190000000000-77738             2             0             0           16
# jcf7190000000000-77764             0             0             0           14
# jcf7190000000000-77784             0             0             0           12
#
#                         DF_p3-minor  DF_p33-major  DF_p33-minor  DF_p34-major  \
# jcf7190000000000-77602            2             0             0            13
# jcf7190000000000-77657            4            10             1            19
# jcf7190000000000-77738            2             7             2            12
# jcf7190000000000-77764            0            11             0            18
# jcf7190000000000-77784            0             9             0            12
#
#                         DF_p34-minor  DF_p35-major  DF_p35-minor  \
# jcf7190000000000-77602             0             9             3
# jcf7190000000000-77657             5             9             4
# jcf7190000000000-77738             6             6             2
# jcf7190000000000-77764             0            11             0
# jcf7190000000000-77784             0             8             0
#
#                         DF_p36-major  DF_p36-minor  DF_p37-major  \
# jcf7190000000000-77602            14             1             9
# jcf7190000000000-77657            14             2             7
# jcf7190000000000-77738            11             2             9
# jcf7190000000000-77764             9             0             0
# jcf7190000000000-77784            10             0             0
#
#                         DF_p37-minor  DF_p38-major  DF_p38-minor  \
# jcf7190000000000-77602             2            21             3
# jcf7190000000000-77657             4            20             4
# jcf7190000000000-77738             1            15             2
# jcf7190000000000-77764             0            13             1
# jcf7190000000000-77784             0            16             0
#
#                         DF_p39-major  DF_p39-minor  DF_p4-major  DF_p4-minor  \
# jcf7190000000000-77602            16             3           14            2
# jcf7190000000000-77657            21             2           10            2
# jcf7190000000000-77738            10             2            9            2
# jcf7190000000000-77764            12             1           11            0
# jcf7190000000000-77784            11             2            7            1
#
#                         DF_p40-major  DF_p40-minor  DF_p41-major  \
# jcf7190000000000-77602             0             0             0
# jcf7190000000000-77657             0             0             8
# jcf7190000000000-77738             0             0             6
# jcf7190000000000-77764             0             0             8
# jcf7190000000000-77784             0             0             0
#
#                         DF_p41-minor  DF_p42-major  DF_p42-minor  \
# jcf7190000000000-77602             0             6             2
# jcf7190000000000-77657             6             7             2
# jcf7190000000000-77738             5             6             3
# jcf7190000000000-77764             1             7             2
# jcf7190000000000-77784             0             6             2
#
#                         DF_p43-major  DF_p43-minor  DF_p44-major  \
# jcf7190000000000-77602            13             6            15
# jcf7190000000000-77657            15             8            16
# jcf7190000000000-77738            10             7            10
# jcf7190000000000-77764            10             6            14
# jcf7190000000000-77784            12             7            12
#
#                         DF_p44-minor  DF_p45-major  DF_p45-minor  \
# jcf7190000000000-77602             1            11             2
# jcf7190000000000-77657             5            15             2
# jcf7190000000000-77738             5            11             4
# jcf7190000000000-77764             2            11             1
# jcf7190000000000-77784             2            13             1
#
#                         DF_p46-major  DF_p46-minor  DF_p47-major  \
# jcf7190000000000-77602            12             1             0
# jcf7190000000000-77657            15             6             0
# jcf7190000000000-77738             6             2             0
# jcf7190000000000-77764             0             0             0
# jcf7190000000000-77784             0             0             0
#
#                         DF_p47-minor  DF_p48-major  DF_p48-minor  \
# jcf7190000000000-77602             0             6             3
# jcf7190000000000-77657             0             9             2
# jcf7190000000000-77738             0             7             3
# jcf7190000000000-77764             0             7             1
# jcf7190000000000-77784             0             0             0
#
#                         DF_p49-major  DF_p49-minor  DF_p5-major  DF_p5-minor  \
# jcf7190000000000-77602            11             4           21            2
# jcf7190000000000-77657            14             0           21            4
# jcf7190000000000-77738            11             0           15            3
# jcf7190000000000-77764             9             0           14            0
# jcf7190000000000-77784             9             1           13            0
#
#                         DF_p54-major  DF_p54-minor  DF_p55-major  \
# jcf7190000000000-77602            13             5             7
# jcf7190000000000-77657            22             3            13
# jcf7190000000000-77738            15             5             9
# jcf7190000000000-77764            16             0            10
# jcf7190000000000-77784            12             1             8
#
#                         DF_p55-minor  DF_p56-major  DF_p56-minor  \
# jcf7190000000000-77602             8             0             0
# jcf7190000000000-77657             4             8             2
# jcf7190000000000-77738             3             6             4
# jcf7190000000000-77764             2            12             0
# jcf7190000000000-77784             4            10             1
#
#                         DF_p57-major  DF_p57-minor  DF_p58-major  \
# jcf7190000000000-77602            11             2             7
# jcf7190000000000-77657            16             4             9
# jcf7190000000000-77738            12             1            11
# jcf7190000000000-77764            11             0            15
# jcf7190000000000-77784            10             1            14
#
#                         DF_p58-minor  DF_p59-major  DF_p59-minor  DF_p6-major  \
# jcf7190000000000-77602             1             0             0            0
# jcf7190000000000-77657             4            10             1            0
# jcf7190000000000-77738             3             9             3            0
# jcf7190000000000-77764             1            10             2            0
# jcf7190000000000-77784             2             7             1            0
#
#                         DF_p6-minor  DF_p60-major  DF_p60-minor  DF_p61-major  \
# jcf7190000000000-77602            0            13             0            21
# jcf7190000000000-77657            0            16             6            22
# jcf7190000000000-77738            0            15             2            13
# jcf7190000000000-77764            0            12             0            14
# jcf7190000000000-77784            0             9             0            13
#
#                         DF_p61-minor  DF_p62-major  DF_p62-minor  DF_p7-major  \
# jcf7190000000000-77602             5            14             6            0
# jcf7190000000000-77657             8            17             2           16
# jcf7190000000000-77738             4            13             1           14
# jcf7190000000000-77764             2            14             0           11
# jcf7190000000000-77784             1            15             0           11
#
#                         DF_p7-minor  DF_p8-major  DF_p8-minor  DF_p85-major  \
# jcf7190000000000-77602            0           12            2             9
# jcf7190000000000-77657            2           19            2            17
# jcf7190000000000-77738            3           14            0            16
# jcf7190000000000-77764            2           11            0            14
# jcf7190000000000-77784            1            0            0            12
#
#                         DF_p85-minor  DF_p86-major  DF_p86-minor  \
# jcf7190000000000-77602             2             7             2
# jcf7190000000000-77657             2            15             3
# jcf7190000000000-77738             3            15             3
# jcf7190000000000-77764             2            15             2
# jcf7190000000000-77784             3            11             2
#
#                         DF_p87-major  DF_p87-minor  DF_p88-major  \
# jcf7190000000000-77602            10             2            10
# jcf7190000000000-77657            16             1            13
# jcf7190000000000-77738            10             0             0
# jcf7190000000000-77764            10             0             8
# jcf7190000000000-77784             8             0             9
#
#                         DF_p88-minor  DF_p89-major  DF_p89-minor  DF_p9-major  \
# jcf7190000000000-77602             0            12             3            9
# jcf7190000000000-77657             2            18             5           12
# jcf7190000000000-77738             0            22             3            0
# jcf7190000000000-77764             1            17             1           10
# jcf7190000000000-77784             0             8             2            9
#
#                         DF_p9-minor  DF_p94-major  DF_p94-minor
# jcf7190000000000-77602            2             8             4
# jcf7190000000000-77657            5            14             4
# jcf7190000000000-77738            0            12             2
# jcf7190000000000-77764            0            10             0
# jcf7190000000000-77784            0             9             3

# %%
smallcols = [col.split("-major")[0] for col in smallgfile.columns if 'major' in col]
len(smallcols)
# Out:
# 42

# %%
all(smallcols == poolsizefile.columns)
# Out:
# True

# %%
# assert missing data looks right (<25%)
majorcols = [col for col in smallgfile if 'major' in col]
for locus in nb(smallgfile.index):
    missingcount = 0
    for col in majorcols:
        if smallgfile.loc[locus, col] == 0 and smallgfile.loc[locus, col.replace("-major", "-minor")] == 0:
            missingcount += 1
    if missingcount/len(majorcols) > 0.25:
        print(locus)
        break
# Out:
# 100%|██████████| 10000/10000 [00:05<00:00, 1806.58it/s]

# %%
missingcount/len(majorcols)
# Out:
# 0.0

# %% [markdown]
# # Transfer files to cedar to run baypass

# %%
from pythonimports import *

# %%
# get engines
lview,dview = get_client()
# Out:
# 56 56

# %%
gfile_dir = '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/individual_gfiles'
gfile_dir
# Out:
# '/data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/individual_gfiles'

# %%
def exe(file, dst):
    """Create rsync command."""
    import subprocess
    import shutil
    output = subprocess.check_output([shutil.which('rsync'), '-avz', file, 'graham:%s' % dst]).decode('utf-8').replace("\n", "").split()[-1]
    return output

# %%
# get some directories so I can make them on graham
dirs = getdirs(baydir)
# Out:
# converting to list
# /data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass
# /data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/individual_efiles
# /data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/individual_gfiles
# /data/projects/pool_seq/DF_datasets/DF_pooled_GEA/DF_pooled/snpsANDindels/interior_variety/03_maf-p05_RD-recalculated_FDI/baypass/neutral_runs_nval_30000_thr_6

# %%
# print mkdir statements, not perfect but good enough
cedardir = '/project/def-saitken/interior'
# cedardir = '/scratch/lindb/interior/baypass'
for d in dirs:
    bname = d.split("/03_maf-p05_RD-recalculated_FDI/")[-1]
    dst = op.join(cedardir, bname)
    print('mkdir -p %s' % dst)
# Out:
# mkdir -p /project/def-saitken/interior/baypass
# mkdir -p /project/def-saitken/interior/baypass/individual_efiles
# mkdir -p /project/def-saitken/interior/baypass/individual_gfiles
# mkdir -p /project/def-saitken/interior/baypass/neutral_runs_nval_30000_thr_6

# %%
# get all of the files from the interior baydir
files = []
for d in dirs:
    files.extend(fs(d, dirs=False))
len(files)
# Out:
# 2171

# %%
# copy all files to graham (beluga the second time, graham is being slow to schedule)
jobs = []
for count,f in enumerate(files):
    bname = f.split("03_maf-p05_RD-recalculated_FDI/")[-1]
    dst = op.join('/project/def-saitken/interior', bname)
    jobs.append(lview.apply_async(exe, *(f, dst)))
watch_async(jobs)
# Out:
# 2171
# 2171

# %%
# check that no jobs produced any errors
needed = []
for i,j in enumerate(jobs):
    if j.ready():
        try:
            x = j.r
        except:
            needed.append(i)
needed
# Out:
# [30,
#  32,
#  33,
#  37,
#  38,
#  39,
#  42,
#  45,
#  51,
#  52,
#  53,
#  54,
#  57,
#  62,
#  65,
#  66,
#  70,
#  71,
#  72,
#  74,
#  80,
#  83,
#  86,
#  89]

# %%
x
# Out:
# '130,627.60'

# %%
jobs = []
for i in needed:
    f = files[i]
    bname = f.split("03_maf-p05_RD-recalculated_FDI/")[-1]
    dst = op.join('/project/def-saitken/interior', bname)
    jobs.append(lview.apply_async(exe, *(f, dst)))
watch_async(jobs)
# Out:
# 2
# 2

# %%
??exe
